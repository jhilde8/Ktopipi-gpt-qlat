# %%
import qlat as q
import numpy as np

# %%
dst_pp = "/home/jhildebrand28/ktopipi/results/48I/auto-contract-I0D5-p/traj-1172/pipi_corr_psnk_psrc.lat"

ld_pp = q.load_lat_data(dst_pp)
ld_pp.info()[0][2]
# Out:
# ['< 1 >  exprs[0]',
#  '< sigma^dag(0) * sigma(-tsep) >  exprs[1]',
#  '< wf_src(0) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_pps)  exprs[2]',
#  '< wf_src(0) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_pps)  exprs[3]',
#  '< wf_src(0) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_spp)  exprs[4]',
#  '< wf_src(0) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_spp)  exprs[5]',
#  '< wf_snk(0) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[6]',
#  '< wf_snk(0) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[7]',
#  '< wf_snk(0) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[8]',
#  '< wf_snk(0) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[9]',
#  '< wf_snk(1) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[10]',
#  '< wf_snk(1) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[11]',
#  '< wf_snk(1) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[12]',
#  '< wf_snk(1) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[13]',
#  '< wf_snk(2) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[14]',
#  '< wf_snk(2) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[15]',
#  '< wf_snk(2) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[16]',
#  '< wf_snk(2) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[17]',
#  '< wf_snk(3) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[18]',
#  '< wf_snk(3) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[19]',
#  '< wf_snk(3) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[20]',
#  '< wf_snk(3) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[21]',
#  '< wf_src(1) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_pps)  exprs[22]',
#  '< wf_src(1) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_pps)  exprs[23]',
#  '< wf_src(1) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_spp)  exprs[24]',
#  '< wf_src(1) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_spp)  exprs[25]',
#  '< wf_snk(0) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[26]',
#  '< wf_snk(0) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[27]',
#  '< wf_snk(0) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[28]',
#  '< wf_snk(0) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[29]',
#  '< wf_snk(1) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[30]',
#  '< wf_snk(1) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[31]',
#  '< wf_snk(1) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[32]',
#  '< wf_snk(1) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[33]',
#  '< wf_snk(2) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[34]',
#  '< wf_snk(2) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[35]',
#  '< wf_snk(2) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[36]',
#  '< wf_snk(2) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[37]',
#  '< wf_snk(3) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[38]',
#  '< wf_snk(3) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[39]',
#  '< wf_snk(3) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[40]',
#  '< wf_snk(3) * wf_src(1) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[41]',
#  '< wf_src(2) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_pps)  exprs[42]',
#  '< wf_src(2) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_pps)  exprs[43]',
#  '< wf_src(2) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_spp)  exprs[44]',
#  '< wf_src(2) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_spp)  exprs[45]',
#  '< wf_snk(0) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[46]',
#  '< wf_snk(0) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[47]',
#  '< wf_snk(0) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[48]',
#  '< wf_snk(0) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[49]',
#  '< wf_snk(1) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[50]',
#  '< wf_snk(1) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[51]',
#  '< wf_snk(1) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[52]',
#  '< wf_snk(1) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[53]',
#  '< wf_snk(2) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[54]',
#  '< wf_snk(2) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[55]',
#  '< wf_snk(2) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[56]',
#  '< wf_snk(2) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[57]',
#  '< wf_snk(3) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[58]',
#  '< wf_snk(3) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[59]',
#  '< wf_snk(3) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[60]',
#  '< wf_snk(3) * wf_src(2) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[61]',
#  '< wf_src(3) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_pps)  exprs[62]',
#  '< wf_src(3) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_pps)  exprs[63]',
#  '< wf_src(3) * sigma^dag(0) * pipi_i00(-tsep) > (ADT1_spp)  exprs[64]',
#  '< wf_src(3) * sigma^dag(0) * pipi_i00(-tsep) > (ADT2_spp)  exprs[65]',
#  '< wf_snk(0) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[66]',
#  '< wf_snk(0) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[67]',
#  '< wf_snk(0) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[68]',
#  '< wf_snk(0) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[69]',
#  '< wf_snk(1) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[70]',
#  '< wf_snk(1) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[71]',
#  '< wf_snk(1) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[72]',
#  '< wf_snk(1) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[73]',
#  '< wf_snk(2) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[74]',
#  '< wf_snk(2) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[75]',
#  '< wf_snk(2) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[76]',
#  '< wf_snk(2) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[77]',
#  '< wf_snk(3) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[78]',
#  '< wf_snk(3) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT2)  exprs[79]',
#  '< wf_snk(3) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT3)  exprs[80]',
#  '< wf_snk(3) * wf_src(3) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT4)  exprs[81]']

# %% [markdown]
# The goal here is to parse the expression strings returned in this info array for the lattide data such that for ANY two point correlation function we can use a hash table to lookup the expression index for a given two point (or three point?) correlator. This is incredibly useful for data analysis, because if we know the operators we used in the expressions, parsing the exact indices and patterns based on diagram type etc is very specific to a calculation, I want to run the lattice data through the parser and then be able to just look up the diagram types or expression indices from what I know I calculated.
#
# This requires us to parse each string, starting by breaking up each string into the individual terms. First, we will split the correlator expression, type, and index, and then within the correlator expression we will save the sink and source operator and wave function, along with the diagram type and expression index in a dictionary. From here, we have one dictionary for each expression, and I want to put the sink wave function and operator together to form an operator

# %%
#parser class for lattice data loaded in from the qlattice auto-contractor
class LatData_parser:
    def __init__(self, lattice_data):
        self.lattice_data = lattice_data
        self.data_array = lattice_data.to_numpy()
        self.info_list = lattice_data.info()[0]
        self.nexp = info_list[1]
        self.expr_list = info_list[2]

    def parse_expr_names(self):
        expr_map = {}

        for i, expr_names in enumerate(self.expr_list):

# %%
class Expression:
    def __init__(self, expr_string):
        self.expr = expr_string

        self.op_src = None
        self.op_snk = None
        self.wf_src = 0
        self.wf_snk = 0
        self.idx = 0
        self.diagram_type = None
        
        pass

class Operator: 
    def __init__(self):
        self.mom = 0
        self.name=None

# %%
import re
s = '< wf_snk(2) * wf_src(0) * pipi_i00^dag(0) * pipi_i00(-tsep) > (ADT1)  exprs[14]'
angle = re.compile(r'<(.*)>')
diagram_type = re.compile(r'\((ADT[\d_]+)\)')
index = re.compile(r'exprs\[(\d+)\]')
match = angle.search(s)
print(match.group(1))
