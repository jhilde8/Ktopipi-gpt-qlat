# %%
import gpt as g
import numpy as np
import os, sys
# Out:
# SharedMemoryMpi:  World communicator of size 1
# SharedMemoryMpi:  Node  communicator of size 1
# SharedMemoryMpi: SharedMemoryAllocate 1073741824 MMAP anonymous implementation
#
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
# __|_ |  |  |  |  |  |  |  |  |  |  |  | _|__
# __|_                                    _|__
# __|_   GGGG    RRRR    III    DDDD      _|__
# __|_  G        R   R    I     D   D     _|__
# __|_  G        R   R    I     D    D    _|__
# __|_  G  GG    RRRR     I     D    D    _|__
# __|_  G   G    R  R     I     D   D     _|__
# __|_   GGGG    R   R   III    DDDD      _|__
# __|_                                    _|__
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
# __|__|__|__|__|__|__|__|__|__|__|__|__|__|__
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |
#
#
# Copyright (C) 2015 Peter Boyle, Azusa Yamaguchi, Guido Cossu, Antonin Portelli and other authors
#
# This program is free software; you can redistribute it and/or modify
# it under the terms of the GNU General Public License as published by
# the Free Software Foundation; either version 2 of the License, or
# (at your option) any later version.
#
# This program is distributed in the hope that it will be useful,
# but WITHOUT ANY WARRANTY; without even the implied warranty of
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# GNU General Public License for more details.
# Current Grid git commit hash is undefined. Check makefile.
#
# Grid : Message : ================================================
# Grid : Message : MPI is initialised and logging filters activated
# Grid : Message : ================================================
# Grid : Message : This rank is running on host lattice01
# Grid : Message : Requested 1073741824 byte stencil comms buffers
# Grid : Message : MemoryManager::Init() setting up
# Grid : Message : MemoryManager::Init() cache pool for recent host   allocations: SMALL 8 LARGE 2 HUGE 0
# Grid : Message : MemoryManager::Init() cache pool for recent device allocations: SMALL 16 LARGE 8 Huge 0
# Grid : Message : MemoryManager::Init() cache pool for recent shared allocations: SMALL 16 LARGE 8 Huge 0
# Grid : Message : MemoryManager::Init() Unified memory space
#
# =============================================
#               Initialized GPT
#      Copyright (C) 2020 Christoph Lehner
# =============================================

# %%
fn_idx = "/data1/qcddata2/48I/psel-prop-psrc-light/traj-1122.qar.idx"
fn_qar = "/data1/qcddata2/48I/psel-prop-psrc-light.qar"

# %%
class qar_prop_io:
    def __init__(self,path):
        self.path = path
        self.fdimensions = []
        self.bytes_header = -1
        self.verbose = g.default.is_verbose("io")
        self.size = 1
        self.header_length = 24
        self.data_start_position = 0
        self.trajectory_offsets = {} #dict for the byte offsets within each trajectory .qar file
        self.file_entries = [] #list to hold dictionaries for each file type within the main .qar file
        g.barrier()

    def read_header(self):
        #ensure it is a file
        if not os.path.isfile(self.path):
            g.message("File does not exist")
            return False

        with open(self.path, "rb") as f:
            try: 
                line = self.getline(f) #grabs first line of the file looking for some sort of header
            except UnicodeDecodeError:
                return False

            #if this hits we are reading the index file, not the main qar file. 
            if line == "#!/usr/bin/env qar-idx-glimpse":
                g.message("reading index file")
                #do something else related to the index file here. 
                
            elif line == "#!/usr/bin/env qar-glimpse":
                g.message("reading main .qar file")
                

            if self.verbose:
                g.message(f"Qlattice file format; reading {self.path}")
                g.message(f"   {line}")

            header = True

            while header:
                line = self.getline(f)
                if self.verbose:
                    g.message(f"\t{line}")

                if line == "END_HEADER":
                    self.data_start_position = f.tell()
                    header = False

                    if self.verbose:
                        g.message(f"Header ends at byte position: {self.data_start_position}")
                    

    def getline(self, f):
        return f.readline().decode("utf-8").strip()

    def read_prop_data(self):
        #after the header the data is binary propagator data. 
        # We need to know the format of the binary data, and also the GPT type that the propagators need to be loaded into

        
        return 0

# %%
#goal of this class is to fill the prop_offsets dictionary with byte locations for all propagator data for each point
#in a single trajectory. 
class qar_idx_prop_io:
    def __init__(self, path):
        self.path = path
        self.prop_offsets = {} #dictionary to hold propagator byte offsets for a particular trajectory.
        self.verbose = False #g.default.is_verbose("io")

    def read_idx(self):
        if not os.path.isfile(self.path):
            g.message("file does not exist")
            return False

        with open(self.path, "rb") as f:
            current_entry = {}
            if self.verbose:
                g.message(f"Qlattice file format; reading {self.path}")
            
            for line in f:
                try:
                    line = line.decode("utf-8").strip()
                except UnicodeDecodeError:
                    return False

                if not line:
                    continue

                #line = self.getline(f).strip()
                
                if self.verbose:
                    g.message(f"Index line: {line}") #have a peek at the line

                #start a block
                if line.startswith("QAR-FILE-IDX"):
                    parts = line.split() #split the line by whitespace, save as a list. This will always have four entries
                    if len(parts) >= 4:
                        current_entry = {
                            "type": parts[1],
                            "index": parts[2],
                            "format": parts[3],
                            "xg": None,
                            "accuracy": None,
                            "offsets": None,
                            "wsnk": False
                        }

                elif current_entry and current_entry["xg"]  is None:
                    if line == "checkpoint.txt":
                        current_entry["xg"] = "checkpoint.txt"
                        current_entry['accuracy'] = 0
                    else:    
                        parts = line.split(" ; ")
                        if len(parts) >= 4:
                            current_entry['wsnk'] = True
                        elif len(parts) >= 3:
                            current_entry['wsnk'] = False
                            
                        current_entry['xg'] = parts[0]
                        #current_entry['type'] = parts[1] It seems like this is already set in the first line. 
                        current_entry['accuracy'] = parts[2]

                elif current_entry and current_entry["offsets"] is None:
                    offsets = [int(x) for x in line.split()]
                    current_entry['offsets'] = offsets


                    #composite key to look at all variations for a given position[
                    key = f"{current_entry['xg']};{current_entry['accuracy']}"
                    
                    self.prop_offsets[key] = {
                        "offsets": offsets,
                        "xg":current_entry['xg'],
                        "wsnk": current_entry["wsnk"],
                        "accuracy": current_entry["accuracy"], #maybe add more if necessary
                        "index": current_entry["index"],
                    }
                    
                    
    def getline(self, f):
        return f.decode("utf-8").strip()

# %%
q_idx = qar_idx_prop_io(fn_idx)
q_idx.read_idx()

# %%
entry = q_idx.prop_offsets.get("xg=(0,2,24,26);accuracy=1")
if entry:
    print(f"Offsets: {entry['offsets']}")
    print(f"Wall sink: {entry['wsnk']}") 
    print(f"Accuracy: {entry['accuracy']}")
else:
    print("Propagator not found")
# Out:
# Propagator not found

# %%
# Find all variants of a point
xg_point = "xg=(0,1,38,62)"
for key in q_idx.prop_offsets:
    if xg_point in key:
        print(f"{key}: {q_idx.prop_offsets[key]} \n")
# Out:
# xg=(0,1,38,62);wall_sink:True;accuracy=0: {'offsets': [62, 83, 131, 132, 221451, 47, 0, 221317], 'xg': 'xg=(0,1,38,62)', 'wsnk': True, 'accuracy': 'accuracy=0', 'index': '1'}
#
# xg=(0,1,38,62);wall_sink:False;accuracy=0.lat: {'offsets': [221451, 221473, 221514, 221515, 4940245, 40, 0, 4718728], 'xg': 'xg=(0,1,38,62)', 'wsnk': False, 'accuracy': 'accuracy=0.lat', 'index': '2'}
#
# xg=(0,1,38,62);wall_sink:True;accuracy=1: {'offsets': [4940245, 4940266, 4940314, 4940315, 5161634, 47, 0, 221317], 'xg': 'xg=(0,1,38,62)', 'wsnk': True, 'accuracy': 'accuracy=1', 'index': '3'}
#
# xg=(0,1,38,62);wall_sink:False;accuracy=1.lat: {'offsets': [5161634, 5161656, 5161697, 5161698, 9880428, 40, 0, 4718728], 'xg': 'xg=(0,1,38,62)', 'wsnk': False, 'accuracy': 'accuracy=1.lat', 'index': '4'}

# %%
for i,key in enumerate(q_idx.prop_offsets.keys()):
    print(f"{i}, {key}")
# Out:
# 0, checkpoint.txt;wall_sink:False;0
# 1, xg=(0,1,38,62);wall_sink:True;accuracy=0
# 2, xg=(0,1,38,62);wall_sink:False;accuracy=0.lat
# 3, xg=(0,1,38,62);wall_sink:True;accuracy=1
# 4, xg=(0,1,38,62);wall_sink:False;accuracy=1.lat
# 5, xg=(0,15,25,38);wall_sink:True;accuracy=0
# 6, xg=(0,15,25,38);wall_sink:False;accuracy=0.lat
# 7, xg=(0,16,24,84);wall_sink:True;accuracy=0
# 8, xg=(0,16,24,84);wall_sink:False;accuracy=0.lat
# 9, xg=(0,16,6,4);wall_sink:True;accuracy=0
# 10, xg=(0,16,6,4);wall_sink:False;accuracy=0.lat
# 11, xg=(0,2,24,26);wall_sink:True;accuracy=0
# 12, xg=(0,2,24,26);wall_sink:False;accuracy=0.lat
# 13, xg=(0,2,3,54);wall_sink:True;accuracy=0
# 14, xg=(0,2,3,54);wall_sink:False;accuracy=0.lat
# 15, xg=(0,20,4,69);wall_sink:True;accuracy=0
# 16, xg=(0,20,4,69);wall_sink:False;accuracy=0.lat
# 17, xg=(0,25,0,70);wall_sink:True;accuracy=0
# 18, xg=(0,25,0,70);wall_sink:False;accuracy=0.lat
# 19, xg=(0,25,7,43);wall_sink:True;accuracy=0
# 20, xg=(0,25,7,43);wall_sink:False;accuracy=0.lat
# 21, xg=(0,26,2,1);wall_sink:True;accuracy=0
# 22, xg=(0,26,2,1);wall_sink:False;accuracy=0.lat
# 23, xg=(0,26,36,23);wall_sink:True;accuracy=0
# 24, xg=(0,26,36,23);wall_sink:False;accuracy=0.lat
# 25, xg=(0,27,24,83);wall_sink:True;accuracy=0
# 26, xg=(0,27,24,83);wall_sink:False;accuracy=0.lat
# 27, xg=(0,27,24,93);wall_sink:True;accuracy=0
# 28, xg=(0,27,24,93);wall_sink:False;accuracy=0.lat
# 29, xg=(0,27,37,51);wall_sink:True;accuracy=0
# 30, xg=(0,27,37,51);wall_sink:False;accuracy=0.lat
# 31, xg=(0,3,17,71);wall_sink:True;accuracy=0
# 32, xg=(0,3,17,71);wall_sink:False;accuracy=0.lat
# 33, xg=(0,3,41,33);wall_sink:True;accuracy=0
# 34, xg=(0,3,41,33);wall_sink:False;accuracy=0.lat
# 35, xg=(0,30,38,70);wall_sink:True;accuracy=0
# 36, xg=(0,30,38,70);wall_sink:False;accuracy=0.lat
# 37, xg=(0,31,13,56);wall_sink:True;accuracy=0
# 38, xg=(0,31,13,56);wall_sink:False;accuracy=0.lat
# 39, xg=(0,32,38,4);wall_sink:True;accuracy=0
# 40, xg=(0,32,38,4);wall_sink:False;accuracy=0.lat
# 41, xg=(0,32,44,81);wall_sink:True;accuracy=0
# 42, xg=(0,32,44,81);wall_sink:False;accuracy=0.lat
# 43, xg=(0,33,3,49);wall_sink:True;accuracy=0
# 44, xg=(0,33,3,49);wall_sink:False;accuracy=0.lat
# 45, xg=(0,33,39,9);wall_sink:True;accuracy=0
# 46, xg=(0,33,39,9);wall_sink:False;accuracy=0.lat
# 47, xg=(0,37,22,51);wall_sink:True;accuracy=0
# 48, xg=(0,37,22,51);wall_sink:False;accuracy=0.lat
# 49, xg=(0,38,17,44);wall_sink:True;accuracy=0
# 50, xg=(0,38,17,44);wall_sink:False;accuracy=0.lat
# 51, xg=(0,39,20,18);wall_sink:True;accuracy=0
# 52, xg=(0,39,20,18);wall_sink:False;accuracy=0.lat
# 53, xg=(0,4,42,86);wall_sink:True;accuracy=0
# 54, xg=(0,4,42,86);wall_sink:False;accuracy=0.lat
# 55, xg=(0,40,1,86);wall_sink:True;accuracy=0
# 56, xg=(0,40,1,86);wall_sink:False;accuracy=0.lat
# 57, xg=(0,43,19,4);wall_sink:True;accuracy=0
# 58, xg=(0,43,19,4);wall_sink:False;accuracy=0.lat
# 59, xg=(0,43,22,36);wall_sink:True;accuracy=0
# 60, xg=(0,43,22,36);wall_sink:False;accuracy=0.lat
# 61, xg=(0,44,23,59);wall_sink:True;accuracy=0
# 62, xg=(0,44,23,59);wall_sink:False;accuracy=0.lat
# 63, xg=(0,44,39,47);wall_sink:True;accuracy=0
# 64, xg=(0,44,39,47);wall_sink:False;accuracy=0.lat
# 65, xg=(0,45,44,62);wall_sink:True;accuracy=0
# 66, xg=(0,45,44,62);wall_sink:False;accuracy=0.lat
# 67, xg=(0,46,38,24);wall_sink:True;accuracy=0
# 68, xg=(0,46,38,24);wall_sink:False;accuracy=0.lat
# 69, xg=(0,6,17,28);wall_sink:True;accuracy=0
# 70, xg=(0,6,17,28);wall_sink:False;accuracy=0.lat
# 71, xg=(0,6,36,42);wall_sink:True;accuracy=0
# 72, xg=(0,6,36,42);wall_sink:False;accuracy=0.lat
# 73, xg=(1,0,27,47);wall_sink:True;accuracy=0
# 74, xg=(1,0,27,47);wall_sink:False;accuracy=0.lat
# 75, xg=(1,0,31,59);wall_sink:True;accuracy=0
# 76, xg=(1,0,31,59);wall_sink:False;accuracy=0.lat
# 77, xg=(1,1,36,46);wall_sink:True;accuracy=0
# 78, xg=(1,1,36,46);wall_sink:False;accuracy=0.lat
# 79, xg=(1,1,36,8);wall_sink:True;accuracy=0
# 80, xg=(1,1,36,8);wall_sink:False;accuracy=0.lat
# 81, xg=(1,11,47,22);wall_sink:True;accuracy=0
# 82, xg=(1,11,47,22);wall_sink:False;accuracy=0.lat
# 83, xg=(1,15,3,58);wall_sink:True;accuracy=0
# 84, xg=(1,15,3,58);wall_sink:False;accuracy=0.lat
# 85, xg=(1,15,34,43);wall_sink:True;accuracy=0
# 86, xg=(1,15,34,43);wall_sink:False;accuracy=0.lat
# 87, xg=(1,16,14,49);wall_sink:True;accuracy=0
# 88, xg=(1,16,14,49);wall_sink:False;accuracy=0.lat
# 89, xg=(1,16,27,29);wall_sink:True;accuracy=0
# 90, xg=(1,16,27,29);wall_sink:False;accuracy=0.lat
# 91, xg=(1,18,1,16);wall_sink:True;accuracy=0
# 92, xg=(1,18,1,16);wall_sink:False;accuracy=0.lat
# 93, xg=(1,18,9,89);wall_sink:True;accuracy=0
# 94, xg=(1,18,9,89);wall_sink:False;accuracy=0.lat
# 95, xg=(1,19,23,35);wall_sink:True;accuracy=0
# 96, xg=(1,19,23,35);wall_sink:False;accuracy=0.lat
# 97, xg=(1,19,31,87);wall_sink:True;accuracy=0
# 98, xg=(1,19,31,87);wall_sink:False;accuracy=0.lat
# 99, xg=(1,2,18,83);wall_sink:True;accuracy=0
# 100, xg=(1,2,18,83);wall_sink:False;accuracy=0.lat
# 101, xg=(1,21,26,67);wall_sink:True;accuracy=0
# 102, xg=(1,21,26,67);wall_sink:False;accuracy=0.lat
# 103, xg=(1,21,37,10);wall_sink:True;accuracy=0
# 104, xg=(1,21,37,10);wall_sink:False;accuracy=0.lat
# 105, xg=(1,25,34,44);wall_sink:True;accuracy=0
# 106, xg=(1,25,34,44);wall_sink:False;accuracy=0.lat
# 107, xg=(1,27,16,43);wall_sink:True;accuracy=0
# 108, xg=(1,27,16,43);wall_sink:False;accuracy=0.lat
# 109, xg=(1,27,38,70);wall_sink:True;accuracy=0
# 110, xg=(1,27,38,70);wall_sink:False;accuracy=0.lat
# 111, xg=(1,28,45,8);wall_sink:True;accuracy=0
# 112, xg=(1,28,45,8);wall_sink:False;accuracy=0.lat
# 113, xg=(1,29,6,35);wall_sink:True;accuracy=0
# 114, xg=(1,29,6,35);wall_sink:False;accuracy=0.lat
# 115, xg=(1,31,3,0);wall_sink:True;accuracy=0
# 116, xg=(1,31,3,0);wall_sink:False;accuracy=0.lat
# 117, xg=(1,33,36,88);wall_sink:True;accuracy=0
# 118, xg=(1,33,36,88);wall_sink:False;accuracy=0.lat
# 119, xg=(1,33,47,64);wall_sink:True;accuracy=0
# 120, xg=(1,33,47,64);wall_sink:False;accuracy=0.lat
# 121, xg=(1,34,45,88);wall_sink:True;accuracy=0
# 122, xg=(1,34,45,88);wall_sink:False;accuracy=0.lat
# 123, xg=(1,41,41,24);wall_sink:True;accuracy=0
# 124, xg=(1,41,41,24);wall_sink:False;accuracy=0.lat
# 125, xg=(1,42,10,47);wall_sink:True;accuracy=0
# 126, xg=(1,42,10,47);wall_sink:False;accuracy=0.lat
# 127, xg=(1,42,12,73);wall_sink:True;accuracy=0
# 128, xg=(1,42,12,73);wall_sink:False;accuracy=0.lat
# 129, xg=(1,45,25,59);wall_sink:True;accuracy=0
# 130, xg=(1,45,25,59);wall_sink:False;accuracy=0.lat
# 131, xg=(1,47,16,91);wall_sink:True;accuracy=0
# 132, xg=(1,47,16,91);wall_sink:False;accuracy=0.lat
# 133, xg=(1,47,28,72);wall_sink:True;accuracy=0
# 134, xg=(1,47,28,72);wall_sink:False;accuracy=0.lat
# 135, xg=(1,47,40,67);wall_sink:True;accuracy=0
# 136, xg=(1,47,40,67);wall_sink:False;accuracy=0.lat
# 137, xg=(1,47,43,76);wall_sink:True;accuracy=0
# 138, xg=(1,47,43,76);wall_sink:False;accuracy=0.lat
# 139, xg=(1,5,35,35);wall_sink:True;accuracy=0
# 140, xg=(1,5,35,35);wall_sink:False;accuracy=0.lat
# 141, xg=(1,7,21,52);wall_sink:True;accuracy=0
# 142, xg=(1,7,21,52);wall_sink:False;accuracy=0.lat
# 143, xg=(1,8,33,55);wall_sink:True;accuracy=0
# 144, xg=(1,8,33,55);wall_sink:False;accuracy=0.lat
# 145, xg=(10,0,16,38);wall_sink:True;accuracy=0
# 146, xg=(10,0,16,38);wall_sink:False;accuracy=0.lat
# 147, xg=(10,1,5,26);wall_sink:True;accuracy=0
# 148, xg=(10,1,5,26);wall_sink:False;accuracy=0.lat
# 149, xg=(10,11,20,26);wall_sink:True;accuracy=0
# 150, xg=(10,11,20,26);wall_sink:False;accuracy=0.lat
# 151, xg=(10,11,22,90);wall_sink:True;accuracy=0
# 152, xg=(10,11,22,90);wall_sink:False;accuracy=0.lat
# 153, xg=(10,11,42,18);wall_sink:True;accuracy=0
# 154, xg=(10,11,42,18);wall_sink:False;accuracy=0.lat
# 155, xg=(10,14,31,37);wall_sink:True;accuracy=0
# 156, xg=(10,14,31,37);wall_sink:False;accuracy=0.lat
# 157, xg=(10,16,2,89);wall_sink:True;accuracy=0
# 158, xg=(10,16,2,89);wall_sink:False;accuracy=0.lat
# 159, xg=(10,18,23,51);wall_sink:True;accuracy=0
# 160, xg=(10,18,23,51);wall_sink:False;accuracy=0.lat
# 161, xg=(10,18,9,4);wall_sink:True;accuracy=0
# 162, xg=(10,18,9,4);wall_sink:False;accuracy=0.lat
# 163, xg=(10,20,23,59);wall_sink:True;accuracy=0
# 164, xg=(10,20,23,59);wall_sink:False;accuracy=0.lat
# 165, xg=(10,21,29,0);wall_sink:True;accuracy=0
# 166, xg=(10,21,29,0);wall_sink:False;accuracy=0.lat
# 167, xg=(10,22,0,62);wall_sink:True;accuracy=0
# 168, xg=(10,22,0,62);wall_sink:False;accuracy=0.lat
# 169, xg=(10,22,10,88);wall_sink:True;accuracy=0
# 170, xg=(10,22,10,88);wall_sink:False;accuracy=0.lat
# 171, xg=(10,23,6,86);wall_sink:True;accuracy=0
# 172, xg=(10,23,6,86);wall_sink:False;accuracy=0.lat
# 173, xg=(10,24,15,53);wall_sink:True;accuracy=0
# 174, xg=(10,24,15,53);wall_sink:False;accuracy=0.lat
# 175, xg=(10,24,19,86);wall_sink:True;accuracy=0
# 176, xg=(10,24,19,86);wall_sink:False;accuracy=0.lat
# 177, xg=(10,24,24,21);wall_sink:True;accuracy=0
# 178, xg=(10,24,24,21);wall_sink:False;accuracy=0.lat
# 179, xg=(10,24,3,32);wall_sink:True;accuracy=0
# 180, xg=(10,24,3,32);wall_sink:False;accuracy=0.lat
# 181, xg=(10,24,37,12);wall_sink:True;accuracy=0
# 182, xg=(10,24,37,12);wall_sink:False;accuracy=0.lat
# 183, xg=(10,24,4,19);wall_sink:True;accuracy=0
# 184, xg=(10,24,4,19);wall_sink:False;accuracy=0.lat
# 185, xg=(10,25,30,29);wall_sink:True;accuracy=0
# 186, xg=(10,25,30,29);wall_sink:False;accuracy=0.lat
# 187, xg=(10,26,13,23);wall_sink:True;accuracy=0
# 188, xg=(10,26,13,23);wall_sink:False;accuracy=0.lat
# 189, xg=(10,26,4,95);wall_sink:True;accuracy=0
# 190, xg=(10,26,4,95);wall_sink:False;accuracy=0.lat
# 191, xg=(10,27,6,67);wall_sink:True;accuracy=0
# 192, xg=(10,27,6,67);wall_sink:False;accuracy=0.lat
# 193, xg=(10,28,12,11);wall_sink:True;accuracy=0
# 194, xg=(10,28,12,11);wall_sink:False;accuracy=0.lat
# 195, xg=(10,28,38,32);wall_sink:True;accuracy=0
# 196, xg=(10,28,38,32);wall_sink:False;accuracy=0.lat
# 197, xg=(10,30,13,16);wall_sink:True;accuracy=0
# 198, xg=(10,30,13,16);wall_sink:False;accuracy=0.lat
# 199, xg=(10,31,40,66);wall_sink:True;accuracy=0
# 200, xg=(10,31,40,66);wall_sink:False;accuracy=0.lat
# 201, xg=(10,34,41,58);wall_sink:True;accuracy=0
# 202, xg=(10,34,41,58);wall_sink:False;accuracy=0.lat
# 203, xg=(10,34,43,74);wall_sink:True;accuracy=0
# 204, xg=(10,34,43,74);wall_sink:False;accuracy=0.lat
# 205, xg=(10,36,38,30);wall_sink:True;accuracy=0
# 206, xg=(10,36,38,30);wall_sink:False;accuracy=0.lat
# 207, xg=(10,39,16,89);wall_sink:True;accuracy=0
# 208, xg=(10,39,16,89);wall_sink:False;accuracy=0.lat
# 209, xg=(10,39,34,33);wall_sink:True;accuracy=0
# 210, xg=(10,39,34,33);wall_sink:False;accuracy=0.lat
# 211, xg=(10,4,26,69);wall_sink:True;accuracy=0
# 212, xg=(10,4,26,69);wall_sink:False;accuracy=0.lat
# 213, xg=(10,4,27,26);wall_sink:True;accuracy=0
# 214, xg=(10,4,27,26);wall_sink:False;accuracy=0.lat
# 215, xg=(10,4,46,77);wall_sink:True;accuracy=0
# 216, xg=(10,4,46,77);wall_sink:False;accuracy=0.lat
# 217, xg=(10,41,39,30);wall_sink:True;accuracy=0
# 218, xg=(10,41,39,30);wall_sink:False;accuracy=0.lat
# 219, xg=(10,42,44,50);wall_sink:True;accuracy=0
# 220, xg=(10,42,44,50);wall_sink:False;accuracy=0.lat
# 221, xg=(10,43,29,60);wall_sink:True;accuracy=0
# 222, xg=(10,43,29,60);wall_sink:False;accuracy=0.lat
# 223, xg=(10,43,32,20);wall_sink:True;accuracy=0
# 224, xg=(10,43,32,20);wall_sink:False;accuracy=0.lat
# 225, xg=(10,43,40,93);wall_sink:True;accuracy=0
# 226, xg=(10,43,40,93);wall_sink:False;accuracy=0.lat
# 227, xg=(10,44,39,3);wall_sink:True;accuracy=0
# 228, xg=(10,44,39,3);wall_sink:False;accuracy=0.lat
# 229, xg=(10,47,23,43);wall_sink:True;accuracy=0
# 230, xg=(10,47,23,43);wall_sink:False;accuracy=0.lat
# 231, xg=(10,5,29,13);wall_sink:True;accuracy=0
# 232, xg=(10,5,29,13);wall_sink:False;accuracy=0.lat
# 233, xg=(10,5,41,73);wall_sink:True;accuracy=0
# 234, xg=(10,5,41,73);wall_sink:False;accuracy=0.lat
# 235, xg=(11,0,6,16);wall_sink:True;accuracy=0
# 236, xg=(11,0,6,16);wall_sink:False;accuracy=0.lat
# 237, xg=(11,1,30,35);wall_sink:True;accuracy=0
# 238, xg=(11,1,30,35);wall_sink:False;accuracy=0.lat
# 239, xg=(11,11,0,63);wall_sink:True;accuracy=0
# 240, xg=(11,11,0,63);wall_sink:False;accuracy=0.lat
# 241, xg=(11,11,21,89);wall_sink:True;accuracy=0
# 242, xg=(11,11,21,89);wall_sink:False;accuracy=0.lat
# 243, xg=(11,12,13,65);wall_sink:True;accuracy=0
# 244, xg=(11,12,13,65);wall_sink:False;accuracy=0.lat
# 245, xg=(11,12,3,51);wall_sink:True;accuracy=0
# 246, xg=(11,12,3,51);wall_sink:False;accuracy=0.lat
# 247, xg=(11,13,42,72);wall_sink:True;accuracy=0
# 248, xg=(11,13,42,72);wall_sink:False;accuracy=0.lat
# 249, xg=(11,14,12,66);wall_sink:True;accuracy=0
# 250, xg=(11,14,12,66);wall_sink:False;accuracy=0.lat
# 251, xg=(11,15,4,89);wall_sink:True;accuracy=0
# 252, xg=(11,15,4,89);wall_sink:False;accuracy=0.lat
# 253, xg=(11,16,27,11);wall_sink:True;accuracy=0
# 254, xg=(11,16,27,11);wall_sink:False;accuracy=0.lat
# 255, xg=(11,20,19,4);wall_sink:True;accuracy=0
# 256, xg=(11,20,19,4);wall_sink:False;accuracy=0.lat
# 257, xg=(11,20,32,37);wall_sink:True;accuracy=0
# 258, xg=(11,20,32,37);wall_sink:False;accuracy=0.lat
# 259, xg=(11,21,26,60);wall_sink:True;accuracy=0
# 260, xg=(11,21,26,60);wall_sink:False;accuracy=0.lat
# 261, xg=(11,21,47,44);wall_sink:True;accuracy=0
# 262, xg=(11,21,47,44);wall_sink:False;accuracy=0.lat
# 263, xg=(11,22,4,30);wall_sink:True;accuracy=0
# 264, xg=(11,22,4,30);wall_sink:False;accuracy=0.lat
# 265, xg=(11,24,6,30);wall_sink:True;accuracy=0
# 266, xg=(11,24,6,30);wall_sink:False;accuracy=0.lat
# 267, xg=(11,25,15,88);wall_sink:True;accuracy=0
# 268, xg=(11,25,15,88);wall_sink:False;accuracy=0.lat
# 269, xg=(11,25,26,55);wall_sink:True;accuracy=0
# 270, xg=(11,25,26,55);wall_sink:False;accuracy=0.lat
# 271, xg=(11,26,27,85);wall_sink:True;accuracy=0
# 272, xg=(11,26,27,85);wall_sink:False;accuracy=0.lat
# 273, xg=(11,29,28,88);wall_sink:True;accuracy=0
# 274, xg=(11,29,28,88);wall_sink:False;accuracy=0.lat
# 275, xg=(11,30,4,56);wall_sink:True;accuracy=0
# 276, xg=(11,30,4,56);wall_sink:False;accuracy=0.lat
# 277, xg=(11,32,27,41);wall_sink:True;accuracy=0
# 278, xg=(11,32,27,41);wall_sink:False;accuracy=0.lat
# 279, xg=(11,33,12,68);wall_sink:True;accuracy=0
# 280, xg=(11,33,12,68);wall_sink:False;accuracy=0.lat
# 281, xg=(11,33,20,79);wall_sink:True;accuracy=0
# 282, xg=(11,33,20,79);wall_sink:False;accuracy=0.lat
# 283, xg=(11,33,35,47);wall_sink:True;accuracy=0
# 284, xg=(11,33,35,47);wall_sink:False;accuracy=0.lat
# 285, xg=(11,33,39,24);wall_sink:True;accuracy=0
# 286, xg=(11,33,39,24);wall_sink:False;accuracy=0.lat
# 287, xg=(11,35,4,77);wall_sink:True;accuracy=0
# 288, xg=(11,35,4,77);wall_sink:False;accuracy=0.lat
# 289, xg=(11,36,3,81);wall_sink:True;accuracy=0
# 290, xg=(11,36,3,81);wall_sink:False;accuracy=0.lat
# 291, xg=(11,37,35,79);wall_sink:True;accuracy=0
# 292, xg=(11,37,35,79);wall_sink:False;accuracy=0.lat
# 293, xg=(11,38,17,16);wall_sink:True;accuracy=0
# 294, xg=(11,38,17,16);wall_sink:False;accuracy=0.lat
# 295, xg=(11,38,25,43);wall_sink:True;accuracy=0
# 296, xg=(11,38,25,43);wall_sink:False;accuracy=0.lat
# 297, xg=(11,39,19,26);wall_sink:True;accuracy=0
# 298, xg=(11,39,19,26);wall_sink:False;accuracy=0.lat
# 299, xg=(11,4,27,28);wall_sink:True;accuracy=0
# 300, xg=(11,4,27,28);wall_sink:False;accuracy=0.lat
# 301, xg=(11,40,16,21);wall_sink:True;accuracy=0
# 302, xg=(11,40,16,21);wall_sink:False;accuracy=0.lat
# 303, xg=(11,40,45,41);wall_sink:True;accuracy=0
# 304, xg=(11,40,45,41);wall_sink:False;accuracy=0.lat
# 305, xg=(11,40,47,66);wall_sink:True;accuracy=0
# 306, xg=(11,40,47,66);wall_sink:False;accuracy=0.lat
# 307, xg=(11,42,45,86);wall_sink:True;accuracy=0
# 308, xg=(11,42,45,86);wall_sink:False;accuracy=0.lat
# 309, xg=(11,43,16,43);wall_sink:True;accuracy=0
# 310, xg=(11,43,16,43);wall_sink:False;accuracy=0.lat
# 311, xg=(11,45,7,52);wall_sink:True;accuracy=0
# 312, xg=(11,45,7,52);wall_sink:False;accuracy=0.lat
# 313, xg=(11,47,29,30);wall_sink:True;accuracy=0
# 314, xg=(11,47,29,30);wall_sink:False;accuracy=0.lat
# 315, xg=(11,47,46,80);wall_sink:True;accuracy=0
# 316, xg=(11,47,46,80);wall_sink:False;accuracy=0.lat
# 317, xg=(11,6,0,18);wall_sink:True;accuracy=0
# 318, xg=(11,6,0,18);wall_sink:False;accuracy=0.lat
# 319, xg=(11,7,21,40);wall_sink:True;accuracy=0
# 320, xg=(11,7,21,40);wall_sink:False;accuracy=0.lat
# 321, xg=(11,8,45,86);wall_sink:True;accuracy=0
# 322, xg=(11,8,45,86);wall_sink:False;accuracy=0.lat
# 323, xg=(12,0,14,10);wall_sink:True;accuracy=0
# 324, xg=(12,0,14,10);wall_sink:False;accuracy=0.lat
# 325, xg=(12,11,14,54);wall_sink:True;accuracy=0
# 326, xg=(12,11,14,54);wall_sink:False;accuracy=0.lat
# 327, xg=(12,11,3,19);wall_sink:True;accuracy=0
# 328, xg=(12,11,3,19);wall_sink:False;accuracy=0.lat
# 329, xg=(12,11,34,8);wall_sink:True;accuracy=0
# 330, xg=(12,11,34,8);wall_sink:False;accuracy=0.lat
# 331, xg=(12,11,7,39);wall_sink:True;accuracy=0
# 332, xg=(12,11,7,39);wall_sink:False;accuracy=0.lat
# 333, xg=(12,15,25,10);wall_sink:True;accuracy=0
# 334, xg=(12,15,25,10);wall_sink:False;accuracy=0.lat
# 335, xg=(12,16,4,10);wall_sink:True;accuracy=0
# 336, xg=(12,16,4,10);wall_sink:False;accuracy=0.lat
# 337, xg=(12,17,34,74);wall_sink:True;accuracy=0
# 338, xg=(12,17,34,74);wall_sink:False;accuracy=0.lat
# 339, xg=(12,18,24,54);wall_sink:True;accuracy=0
# 340, xg=(12,18,24,54);wall_sink:False;accuracy=0.lat
# 341, xg=(12,18,35,21);wall_sink:True;accuracy=0
# 342, xg=(12,18,35,21);wall_sink:False;accuracy=0.lat
# 343, xg=(12,20,46,4);wall_sink:True;accuracy=0
# 344, xg=(12,20,46,4);wall_sink:False;accuracy=0.lat
# 345, xg=(12,21,2,12);wall_sink:True;accuracy=0
# 346, xg=(12,21,2,12);wall_sink:False;accuracy=0.lat
# 347, xg=(12,21,41,17);wall_sink:True;accuracy=0
# 348, xg=(12,21,41,17);wall_sink:False;accuracy=0.lat
# 349, xg=(12,22,12,16);wall_sink:True;accuracy=0
# 350, xg=(12,22,12,16);wall_sink:False;accuracy=0.lat
# 351, xg=(12,23,16,23);wall_sink:True;accuracy=0
# 352, xg=(12,23,16,23);wall_sink:False;accuracy=0.lat
# 353, xg=(12,23,7,88);wall_sink:True;accuracy=0
# 354, xg=(12,23,7,88);wall_sink:False;accuracy=0.lat
# 355, xg=(12,24,18,85);wall_sink:True;accuracy=0
# 356, xg=(12,24,18,85);wall_sink:False;accuracy=0.lat
# 357, xg=(12,25,36,9);wall_sink:True;accuracy=0
# 358, xg=(12,25,36,9);wall_sink:False;accuracy=0.lat
# 359, xg=(12,26,36,81);wall_sink:True;accuracy=0
# 360, xg=(12,26,36,81);wall_sink:False;accuracy=0.lat
# 361, xg=(12,27,14,28);wall_sink:True;accuracy=0
# 362, xg=(12,27,14,28);wall_sink:False;accuracy=0.lat
# 363, xg=(12,27,6,34);wall_sink:True;accuracy=0
# 364, xg=(12,27,6,34);wall_sink:False;accuracy=0.lat
# 365, xg=(12,29,33,0);wall_sink:True;accuracy=0
# 366, xg=(12,29,33,0);wall_sink:False;accuracy=0.lat
# 367, xg=(12,3,38,32);wall_sink:True;accuracy=0
# 368, xg=(12,3,38,32);wall_sink:False;accuracy=0.lat
# 369, xg=(12,31,13,20);wall_sink:True;accuracy=0
# 370, xg=(12,31,13,20);wall_sink:False;accuracy=0.lat
# 371, xg=(12,31,13,20);wall_sink:True;accuracy=1
# 372, xg=(12,31,13,20);wall_sink:False;accuracy=1.lat
# 373, xg=(12,31,38,3);wall_sink:True;accuracy=0
# 374, xg=(12,31,38,3);wall_sink:False;accuracy=0.lat
# 375, xg=(12,36,12,33);wall_sink:True;accuracy=0
# 376, xg=(12,36,12,33);wall_sink:False;accuracy=0.lat
# 377, xg=(12,37,14,7);wall_sink:True;accuracy=0
# 378, xg=(12,37,14,7);wall_sink:False;accuracy=0.lat
# 379, xg=(12,38,20,90);wall_sink:True;accuracy=0
# 380, xg=(12,38,20,90);wall_sink:False;accuracy=0.lat
# 381, xg=(12,39,0,78);wall_sink:True;accuracy=0
# 382, xg=(12,39,0,78);wall_sink:False;accuracy=0.lat
# 383, xg=(12,42,0,2);wall_sink:True;accuracy=0
# 384, xg=(12,42,0,2);wall_sink:False;accuracy=0.lat
# 385, xg=(12,43,20,70);wall_sink:True;accuracy=0
# 386, xg=(12,43,20,70);wall_sink:False;accuracy=0.lat
# 387, xg=(12,45,40,91);wall_sink:True;accuracy=0
# 388, xg=(12,45,40,91);wall_sink:False;accuracy=0.lat
# 389, xg=(12,47,28,48);wall_sink:True;accuracy=0
# 390, xg=(12,47,28,48);wall_sink:False;accuracy=0.lat
# 391, xg=(12,5,44,10);wall_sink:True;accuracy=0
# 392, xg=(12,5,44,10);wall_sink:False;accuracy=0.lat
# 393, xg=(12,6,6,95);wall_sink:True;accuracy=0
# 394, xg=(12,6,6,95);wall_sink:False;accuracy=0.lat
# 395, xg=(12,7,12,77);wall_sink:True;accuracy=0
# 396, xg=(12,7,12,77);wall_sink:False;accuracy=0.lat
# 397, xg=(12,7,24,6);wall_sink:True;accuracy=0
# 398, xg=(12,7,24,6);wall_sink:False;accuracy=0.lat
# 399, xg=(12,7,27,12);wall_sink:True;accuracy=0
# 400, xg=(12,7,27,12);wall_sink:False;accuracy=0.lat
# 401, xg=(12,8,42,43);wall_sink:True;accuracy=0
# 402, xg=(12,8,42,43);wall_sink:False;accuracy=0.lat
# 403, xg=(12,9,2,18);wall_sink:True;accuracy=0
# 404, xg=(12,9,2,18);wall_sink:False;accuracy=0.lat
# 405, xg=(13,0,27,21);wall_sink:True;accuracy=0
# 406, xg=(13,0,27,21);wall_sink:False;accuracy=0.lat
# 407, xg=(13,0,34,52);wall_sink:True;accuracy=0
# 408, xg=(13,0,34,52);wall_sink:False;accuracy=0.lat
# 409, xg=(13,0,7,64);wall_sink:True;accuracy=0
# 410, xg=(13,0,7,64);wall_sink:False;accuracy=0.lat
# 411, xg=(13,10,12,66);wall_sink:True;accuracy=0
# 412, xg=(13,10,12,66);wall_sink:False;accuracy=0.lat
# 413, xg=(13,10,36,70);wall_sink:True;accuracy=0
# 414, xg=(13,10,36,70);wall_sink:False;accuracy=0.lat
# 415, xg=(13,12,13,77);wall_sink:True;accuracy=0
# 416, xg=(13,12,13,77);wall_sink:False;accuracy=0.lat
# 417, xg=(13,13,46,49);wall_sink:True;accuracy=0
# 418, xg=(13,13,46,49);wall_sink:False;accuracy=0.lat
# 419, xg=(13,13,47,77);wall_sink:True;accuracy=0
# 420, xg=(13,13,47,77);wall_sink:False;accuracy=0.lat
# 421, xg=(13,13,9,31);wall_sink:True;accuracy=0
# 422, xg=(13,13,9,31);wall_sink:False;accuracy=0.lat
# 423, xg=(13,16,17,93);wall_sink:True;accuracy=0
# 424, xg=(13,16,17,93);wall_sink:False;accuracy=0.lat
# 425, xg=(13,16,17,93);wall_sink:True;accuracy=1
# 426, xg=(13,16,17,93);wall_sink:False;accuracy=1.lat
# 427, xg=(13,16,29,94);wall_sink:True;accuracy=0
# 428, xg=(13,16,29,94);wall_sink:False;accuracy=0.lat
# 429, xg=(13,16,42,27);wall_sink:True;accuracy=0
# 430, xg=(13,16,42,27);wall_sink:False;accuracy=0.lat
# 431, xg=(13,21,11,68);wall_sink:True;accuracy=0
# 432, xg=(13,21,11,68);wall_sink:False;accuracy=0.lat
# 433, xg=(13,21,33,20);wall_sink:True;accuracy=0
# 434, xg=(13,21,33,20);wall_sink:False;accuracy=0.lat
# 435, xg=(13,23,19,95);wall_sink:True;accuracy=0
# 436, xg=(13,23,19,95);wall_sink:False;accuracy=0.lat
# 437, xg=(13,24,2,7);wall_sink:True;accuracy=0
# 438, xg=(13,24,2,7);wall_sink:False;accuracy=0.lat
# 439, xg=(13,25,20,69);wall_sink:True;accuracy=0
# 440, xg=(13,25,20,69);wall_sink:False;accuracy=0.lat
# 441, xg=(13,25,29,69);wall_sink:True;accuracy=0
# 442, xg=(13,25,29,69);wall_sink:False;accuracy=0.lat
# 443, xg=(13,26,19,78);wall_sink:True;accuracy=0
# 444, xg=(13,26,19,78);wall_sink:False;accuracy=0.lat
# 445, xg=(13,26,43,24);wall_sink:True;accuracy=0
# 446, xg=(13,26,43,24);wall_sink:False;accuracy=0.lat
# 447, xg=(13,27,38,64);wall_sink:True;accuracy=0
# 448, xg=(13,27,38,64);wall_sink:False;accuracy=0.lat
# 449, xg=(13,28,20,83);wall_sink:True;accuracy=0
# 450, xg=(13,28,20,83);wall_sink:False;accuracy=0.lat
# 451, xg=(13,28,38,76);wall_sink:True;accuracy=0
# 452, xg=(13,28,38,76);wall_sink:False;accuracy=0.lat
# 453, xg=(13,29,11,36);wall_sink:True;accuracy=0
# 454, xg=(13,29,11,36);wall_sink:False;accuracy=0.lat
# 455, xg=(13,30,45,29);wall_sink:True;accuracy=0
# 456, xg=(13,30,45,29);wall_sink:False;accuracy=0.lat
# 457, xg=(13,33,30,47);wall_sink:True;accuracy=0
# 458, xg=(13,33,30,47);wall_sink:False;accuracy=0.lat
# 459, xg=(13,34,18,24);wall_sink:True;accuracy=0
# 460, xg=(13,34,18,24);wall_sink:False;accuracy=0.lat
# 461, xg=(13,34,26,30);wall_sink:True;accuracy=0
# 462, xg=(13,34,26,30);wall_sink:False;accuracy=0.lat
# 463, xg=(13,35,8,15);wall_sink:True;accuracy=0
# 464, xg=(13,35,8,15);wall_sink:False;accuracy=0.lat
# 465, xg=(13,36,12,65);wall_sink:True;accuracy=0
# 466, xg=(13,36,12,65);wall_sink:False;accuracy=0.lat
# 467, xg=(13,36,5,32);wall_sink:True;accuracy=0
# 468, xg=(13,36,5,32);wall_sink:False;accuracy=0.lat
# 469, xg=(13,36,6,23);wall_sink:True;accuracy=0
# 470, xg=(13,36,6,23);wall_sink:False;accuracy=0.lat
# 471, xg=(13,36,6,23);wall_sink:True;accuracy=1
# 472, xg=(13,36,6,23);wall_sink:False;accuracy=1.lat
# 473, xg=(13,38,19,71);wall_sink:True;accuracy=0
# 474, xg=(13,38,19,71);wall_sink:False;accuracy=0.lat
# 475, xg=(13,40,10,77);wall_sink:True;accuracy=0
# 476, xg=(13,40,10,77);wall_sink:False;accuracy=0.lat
# 477, xg=(13,41,46,89);wall_sink:True;accuracy=0
# 478, xg=(13,41,46,89);wall_sink:False;accuracy=0.lat
# 479, xg=(13,41,8,6);wall_sink:True;accuracy=0
# 480, xg=(13,41,8,6);wall_sink:False;accuracy=0.lat
# 481, xg=(13,42,21,67);wall_sink:True;accuracy=0
# 482, xg=(13,42,21,67);wall_sink:False;accuracy=0.lat
# 483, xg=(13,44,3,25);wall_sink:True;accuracy=0
# 484, xg=(13,44,3,25);wall_sink:False;accuracy=0.lat
# 485, xg=(13,45,11,51);wall_sink:True;accuracy=0
# 486, xg=(13,45,11,51);wall_sink:False;accuracy=0.lat
# 487, xg=(13,45,14,31);wall_sink:True;accuracy=0
# 488, xg=(13,45,14,31);wall_sink:False;accuracy=0.lat
# 489, xg=(13,5,4,42);wall_sink:True;accuracy=0
# 490, xg=(13,5,4,42);wall_sink:False;accuracy=0.lat
# 491, xg=(13,8,36,94);wall_sink:True;accuracy=0
# 492, xg=(13,8,36,94);wall_sink:False;accuracy=0.lat
# 493, xg=(13,8,41,31);wall_sink:True;accuracy=0
# 494, xg=(13,8,41,31);wall_sink:False;accuracy=0.lat
# 495, xg=(13,9,4,90);wall_sink:True;accuracy=0
# 496, xg=(13,9,4,90);wall_sink:False;accuracy=0.lat
# 497, xg=(14,0,21,22);wall_sink:True;accuracy=0
# 498, xg=(14,0,21,22);wall_sink:False;accuracy=0.lat
# 499, xg=(14,0,28,19);wall_sink:True;accuracy=0
# 500, xg=(14,0,28,19);wall_sink:False;accuracy=0.lat
# 501, xg=(14,1,11,3);wall_sink:True;accuracy=0
# 502, xg=(14,1,11,3);wall_sink:False;accuracy=0.lat
# 503, xg=(14,1,39,41);wall_sink:True;accuracy=0
# 504, xg=(14,1,39,41);wall_sink:False;accuracy=0.lat
# 505, xg=(14,11,14,84);wall_sink:True;accuracy=0
# 506, xg=(14,11,14,84);wall_sink:False;accuracy=0.lat
# 507, xg=(14,11,40,54);wall_sink:True;accuracy=0
# 508, xg=(14,11,40,54);wall_sink:False;accuracy=0.lat
# 509, xg=(14,13,25,74);wall_sink:True;accuracy=0
# 510, xg=(14,13,25,74);wall_sink:False;accuracy=0.lat
# 511, xg=(14,16,4,42);wall_sink:True;accuracy=0
# 512, xg=(14,16,4,42);wall_sink:False;accuracy=0.lat
# 513, xg=(14,17,16,42);wall_sink:True;accuracy=0
# 514, xg=(14,17,16,42);wall_sink:False;accuracy=0.lat
# 515, xg=(14,18,37,26);wall_sink:True;accuracy=0
# 516, xg=(14,18,37,26);wall_sink:False;accuracy=0.lat
# 517, xg=(14,19,1,54);wall_sink:True;accuracy=0
# 518, xg=(14,19,1,54);wall_sink:False;accuracy=0.lat
# 519, xg=(14,2,13,18);wall_sink:True;accuracy=0
# 520, xg=(14,2,13,18);wall_sink:False;accuracy=0.lat
# 521, xg=(14,21,42,83);wall_sink:True;accuracy=0
# 522, xg=(14,21,42,83);wall_sink:False;accuracy=0.lat
# 523, xg=(14,26,11,39);wall_sink:True;accuracy=0
# 524, xg=(14,26,11,39);wall_sink:False;accuracy=0.lat
# 525, xg=(14,28,27,74);wall_sink:True;accuracy=0
# 526, xg=(14,28,27,74);wall_sink:False;accuracy=0.lat
# 527, xg=(14,28,6,65);wall_sink:True;accuracy=0
# 528, xg=(14,28,6,65);wall_sink:False;accuracy=0.lat
# 529, xg=(14,29,0,16);wall_sink:True;accuracy=0
# 530, xg=(14,29,0,16);wall_sink:False;accuracy=0.lat
# 531, xg=(14,29,9,53);wall_sink:True;accuracy=0
# 532, xg=(14,29,9,53);wall_sink:False;accuracy=0.lat
# 533, xg=(14,3,26,95);wall_sink:True;accuracy=0
# 534, xg=(14,3,26,95);wall_sink:False;accuracy=0.lat
# 535, xg=(14,3,43,82);wall_sink:True;accuracy=0
# 536, xg=(14,3,43,82);wall_sink:False;accuracy=0.lat
# 537, xg=(14,30,19,66);wall_sink:True;accuracy=0
# 538, xg=(14,30,19,66);wall_sink:False;accuracy=0.lat
# 539, xg=(14,30,41,80);wall_sink:True;accuracy=0
# 540, xg=(14,30,41,80);wall_sink:False;accuracy=0.lat
# 541, xg=(14,35,31,25);wall_sink:True;accuracy=0
# 542, xg=(14,35,31,25);wall_sink:False;accuracy=0.lat
# 543, xg=(14,36,12,55);wall_sink:True;accuracy=0
# 544, xg=(14,36,12,55);wall_sink:False;accuracy=0.lat
# 545, xg=(14,36,4,58);wall_sink:True;accuracy=0
# 546, xg=(14,36,4,58);wall_sink:False;accuracy=0.lat
# 547, xg=(14,36,4,58);wall_sink:True;accuracy=1
# 548, xg=(14,36,4,58);wall_sink:False;accuracy=1.lat
# 549, xg=(14,37,0,35);wall_sink:True;accuracy=0
# 550, xg=(14,37,0,35);wall_sink:False;accuracy=0.lat
# 551, xg=(14,38,24,6);wall_sink:True;accuracy=0
# 552, xg=(14,38,24,6);wall_sink:False;accuracy=0.lat
# 553, xg=(14,39,33,47);wall_sink:True;accuracy=0
# 554, xg=(14,39,33,47);wall_sink:False;accuracy=0.lat
# 555, xg=(14,39,47,81);wall_sink:True;accuracy=0
# 556, xg=(14,39,47,81);wall_sink:False;accuracy=0.lat
# 557, xg=(14,41,7,73);wall_sink:True;accuracy=0
# 558, xg=(14,41,7,73);wall_sink:False;accuracy=0.lat
# 559, xg=(14,42,12,75);wall_sink:True;accuracy=0
# 560, xg=(14,42,12,75);wall_sink:False;accuracy=0.lat
# 561, xg=(14,42,27,7);wall_sink:True;accuracy=0
# 562, xg=(14,42,27,7);wall_sink:False;accuracy=0.lat
# 563, xg=(14,42,41,88);wall_sink:True;accuracy=0
# 564, xg=(14,42,41,88);wall_sink:False;accuracy=0.lat
# 565, xg=(14,43,29,10);wall_sink:True;accuracy=0
# 566, xg=(14,43,29,10);wall_sink:False;accuracy=0.lat
# 567, xg=(14,44,18,86);wall_sink:True;accuracy=0
# 568, xg=(14,44,18,86);wall_sink:False;accuracy=0.lat
# 569, xg=(14,44,18,86);wall_sink:True;accuracy=1
# 570, xg=(14,44,18,86);wall_sink:False;accuracy=1.lat
# 571, xg=(14,44,18,86);wall_sink:True;accuracy=2
# 572, xg=(14,44,18,86);wall_sink:False;accuracy=2.lat
# 573, xg=(14,45,17,1);wall_sink:True;accuracy=0
# 574, xg=(14,45,17,1);wall_sink:False;accuracy=0.lat
# 575, xg=(14,45,23,1);wall_sink:True;accuracy=0
# 576, xg=(14,45,23,1);wall_sink:False;accuracy=0.lat
# 577, xg=(14,45,34,93);wall_sink:True;accuracy=0
# 578, xg=(14,45,34,93);wall_sink:False;accuracy=0.lat
# 579, xg=(14,46,15,87);wall_sink:True;accuracy=0
# 580, xg=(14,46,15,87);wall_sink:False;accuracy=0.lat
# 581, xg=(14,46,2,33);wall_sink:True;accuracy=0
# 582, xg=(14,46,2,33);wall_sink:False;accuracy=0.lat
# 583, xg=(14,47,37,82);wall_sink:True;accuracy=0
# 584, xg=(14,47,37,82);wall_sink:False;accuracy=0.lat
# 585, xg=(14,47,41,6);wall_sink:True;accuracy=0
# 586, xg=(14,47,41,6);wall_sink:False;accuracy=0.lat
# 587, xg=(14,6,28,84);wall_sink:True;accuracy=0
# 588, xg=(14,6,28,84);wall_sink:False;accuracy=0.lat
# 589, xg=(14,7,1,76);wall_sink:True;accuracy=0
# 590, xg=(14,7,1,76);wall_sink:False;accuracy=0.lat
# 591, xg=(15,1,14,49);wall_sink:True;accuracy=0
# 592, xg=(15,1,14,49);wall_sink:False;accuracy=0.lat
# 593, xg=(15,1,43,60);wall_sink:True;accuracy=0
# 594, xg=(15,1,43,60);wall_sink:False;accuracy=0.lat
# 595, xg=(15,1,44,38);wall_sink:True;accuracy=0
# 596, xg=(15,1,44,38);wall_sink:False;accuracy=0.lat
# 597, xg=(15,12,14,74);wall_sink:True;accuracy=0
# 598, xg=(15,12,14,74);wall_sink:False;accuracy=0.lat
# 599, xg=(15,13,33,68);wall_sink:True;accuracy=0
# 600, xg=(15,13,33,68);wall_sink:False;accuracy=0.lat
# 601, xg=(15,13,42,76);wall_sink:True;accuracy=0
# 602, xg=(15,13,42,76);wall_sink:False;accuracy=0.lat
# 603, xg=(15,14,39,64);wall_sink:True;accuracy=0
# 604, xg=(15,14,39,64);wall_sink:False;accuracy=0.lat
# 605, xg=(15,15,39,47);wall_sink:True;accuracy=0
# 606, xg=(15,15,39,47);wall_sink:False;accuracy=0.lat
# 607, xg=(15,16,30,26);wall_sink:True;accuracy=0
# 608, xg=(15,16,30,26);wall_sink:False;accuracy=0.lat
# 609, xg=(15,18,40,14);wall_sink:True;accuracy=0
# 610, xg=(15,18,40,14);wall_sink:False;accuracy=0.lat
# 611, xg=(15,18,40,14);wall_sink:True;accuracy=1
# 612, xg=(15,18,40,14);wall_sink:False;accuracy=1.lat
# 613, xg=(15,19,12,18);wall_sink:True;accuracy=0
# 614, xg=(15,19,12,18);wall_sink:False;accuracy=0.lat
# 615, xg=(15,19,25,22);wall_sink:True;accuracy=0
# 616, xg=(15,19,25,22);wall_sink:False;accuracy=0.lat
# 617, xg=(15,19,37,20);wall_sink:True;accuracy=0
# 618, xg=(15,19,37,20);wall_sink:False;accuracy=0.lat
# 619, xg=(15,2,8,27);wall_sink:True;accuracy=0
# 620, xg=(15,2,8,27);wall_sink:False;accuracy=0.lat
# 621, xg=(15,20,17,37);wall_sink:True;accuracy=0
# 622, xg=(15,20,17,37);wall_sink:False;accuracy=0.lat
# 623, xg=(15,21,14,67);wall_sink:True;accuracy=0
# 624, xg=(15,21,14,67);wall_sink:False;accuracy=0.lat
# 625, xg=(15,21,21,85);wall_sink:True;accuracy=0
# 626, xg=(15,21,21,85);wall_sink:False;accuracy=0.lat
# 627, xg=(15,21,42,80);wall_sink:True;accuracy=0
# 628, xg=(15,21,42,80);wall_sink:False;accuracy=0.lat
# 629, xg=(15,22,33,26);wall_sink:True;accuracy=0
# 630, xg=(15,22,33,26);wall_sink:False;accuracy=0.lat
# 631, xg=(15,23,33,71);wall_sink:True;accuracy=0
# 632, xg=(15,23,33,71);wall_sink:False;accuracy=0.lat
# 633, xg=(15,25,25,57);wall_sink:True;accuracy=0
# 634, xg=(15,25,25,57);wall_sink:False;accuracy=0.lat
# 635, xg=(15,27,24,70);wall_sink:True;accuracy=0
# 636, xg=(15,27,24,70);wall_sink:False;accuracy=0.lat
# 637, xg=(15,27,33,5);wall_sink:True;accuracy=0
# 638, xg=(15,27,33,5);wall_sink:False;accuracy=0.lat
# 639, xg=(15,28,41,1);wall_sink:True;accuracy=0
# 640, xg=(15,28,41,1);wall_sink:False;accuracy=0.lat
# 641, xg=(15,29,16,75);wall_sink:True;accuracy=0
# 642, xg=(15,29,16,75);wall_sink:False;accuracy=0.lat
# 643, xg=(15,29,6,54);wall_sink:True;accuracy=0
# 644, xg=(15,29,6,54);wall_sink:False;accuracy=0.lat
# 645, xg=(15,30,20,62);wall_sink:True;accuracy=0
# 646, xg=(15,30,20,62);wall_sink:False;accuracy=0.lat
# 647, xg=(15,30,33,58);wall_sink:True;accuracy=0
# 648, xg=(15,30,33,58);wall_sink:False;accuracy=0.lat
# 649, xg=(15,30,4,3);wall_sink:True;accuracy=0
# 650, xg=(15,30,4,3);wall_sink:False;accuracy=0.lat
# 651, xg=(15,33,32,26);wall_sink:True;accuracy=0
# 652, xg=(15,33,32,26);wall_sink:False;accuracy=0.lat
# 653, xg=(15,37,12,37);wall_sink:True;accuracy=0
# 654, xg=(15,37,12,37);wall_sink:False;accuracy=0.lat
# 655, xg=(15,37,15,57);wall_sink:True;accuracy=0
# 656, xg=(15,37,15,57);wall_sink:False;accuracy=0.lat
# 657, xg=(15,38,11,86);wall_sink:True;accuracy=0
# 658, xg=(15,38,11,86);wall_sink:False;accuracy=0.lat
# 659, xg=(15,39,12,87);wall_sink:True;accuracy=0
# 660, xg=(15,39,12,87);wall_sink:False;accuracy=0.lat
# 661, xg=(15,4,13,65);wall_sink:True;accuracy=0
# 662, xg=(15,4,13,65);wall_sink:False;accuracy=0.lat
# 663, xg=(15,4,39,22);wall_sink:True;accuracy=0
# 664, xg=(15,4,39,22);wall_sink:False;accuracy=0.lat
# 665, xg=(15,40,20,19);wall_sink:True;accuracy=0
# 666, xg=(15,40,20,19);wall_sink:False;accuracy=0.lat
# 667, xg=(15,41,10,67);wall_sink:True;accuracy=0
# 668, xg=(15,41,10,67);wall_sink:False;accuracy=0.lat
# 669, xg=(15,41,13,32);wall_sink:True;accuracy=0
# 670, xg=(15,41,13,32);wall_sink:False;accuracy=0.lat
# 671, xg=(15,41,9,47);wall_sink:True;accuracy=0
# 672, xg=(15,41,9,47);wall_sink:False;accuracy=0.lat
# 673, xg=(15,42,5,83);wall_sink:True;accuracy=0
# 674, xg=(15,42,5,83);wall_sink:False;accuracy=0.lat
# 675, xg=(15,42,9,82);wall_sink:True;accuracy=0
# 676, xg=(15,42,9,82);wall_sink:False;accuracy=0.lat
# 677, xg=(15,44,32,22);wall_sink:True;accuracy=0
# 678, xg=(15,44,32,22);wall_sink:False;accuracy=0.lat
# 679, xg=(15,44,34,26);wall_sink:True;accuracy=0
# 680, xg=(15,44,34,26);wall_sink:False;accuracy=0.lat
# 681, xg=(15,44,38,5);wall_sink:True;accuracy=0
# 682, xg=(15,44,38,5);wall_sink:False;accuracy=0.lat
# 683, xg=(15,44,5,88);wall_sink:True;accuracy=0
# 684, xg=(15,44,5,88);wall_sink:False;accuracy=0.lat
# 685, xg=(15,45,28,46);wall_sink:True;accuracy=0
# 686, xg=(15,45,28,46);wall_sink:False;accuracy=0.lat
# 687, xg=(15,45,28,46);wall_sink:True;accuracy=1
# 688, xg=(15,45,28,46);wall_sink:False;accuracy=1.lat
# 689, xg=(15,47,23,66);wall_sink:True;accuracy=0
# 690, xg=(15,47,23,66);wall_sink:False;accuracy=0.lat
# 691, xg=(15,47,41,5);wall_sink:True;accuracy=0
# 692, xg=(15,47,41,5);wall_sink:False;accuracy=0.lat
# 693, xg=(15,5,15,58);wall_sink:True;accuracy=0
# 694, xg=(15,5,15,58);wall_sink:False;accuracy=0.lat
# 695, xg=(15,6,14,1);wall_sink:True;accuracy=0
# 696, xg=(15,6,14,1);wall_sink:False;accuracy=0.lat
# 697, xg=(15,7,25,36);wall_sink:True;accuracy=0
# 698, xg=(15,7,25,36);wall_sink:False;accuracy=0.lat
# 699, xg=(15,8,27,31);wall_sink:True;accuracy=0
# 700, xg=(15,8,27,31);wall_sink:False;accuracy=0.lat
# 701, xg=(16,0,14,34);wall_sink:True;accuracy=0
# 702, xg=(16,0,14,34);wall_sink:False;accuracy=0.lat
# 703, xg=(16,0,45,94);wall_sink:True;accuracy=0
# 704, xg=(16,0,45,94);wall_sink:False;accuracy=0.lat
# 705, xg=(16,10,18,29);wall_sink:True;accuracy=0
# 706, xg=(16,10,18,29);wall_sink:False;accuracy=0.lat
# 707, xg=(16,10,25,3);wall_sink:True;accuracy=0
# 708, xg=(16,10,25,3);wall_sink:False;accuracy=0.lat
# 709, xg=(16,10,37,85);wall_sink:True;accuracy=0
# 710, xg=(16,10,37,85);wall_sink:False;accuracy=0.lat
# 711, xg=(16,11,16,92);wall_sink:True;accuracy=0
# 712, xg=(16,11,16,92);wall_sink:False;accuracy=0.lat
# 713, xg=(16,11,29,76);wall_sink:True;accuracy=0
# 714, xg=(16,11,29,76);wall_sink:False;accuracy=0.lat
# 715, xg=(16,11,42,85);wall_sink:True;accuracy=0
# 716, xg=(16,11,42,85);wall_sink:False;accuracy=0.lat
# 717, xg=(16,11,45,86);wall_sink:True;accuracy=0
# 718, xg=(16,11,45,86);wall_sink:False;accuracy=0.lat
# 719, xg=(16,11,46,16);wall_sink:True;accuracy=0
# 720, xg=(16,11,46,16);wall_sink:False;accuracy=0.lat
# 721, xg=(16,12,25,73);wall_sink:True;accuracy=0
# 722, xg=(16,12,25,73);wall_sink:False;accuracy=0.lat
# 723, xg=(16,17,34,53);wall_sink:True;accuracy=0
# 724, xg=(16,17,34,53);wall_sink:False;accuracy=0.lat
# 725, xg=(16,18,31,6);wall_sink:True;accuracy=0
# 726, xg=(16,18,31,6);wall_sink:False;accuracy=0.lat
# 727, xg=(16,2,7,88);wall_sink:True;accuracy=0
# 728, xg=(16,2,7,88);wall_sink:False;accuracy=0.lat
# 729, xg=(16,21,4,75);wall_sink:True;accuracy=0
# 730, xg=(16,21,4,75);wall_sink:False;accuracy=0.lat
# 731, xg=(16,22,24,22);wall_sink:True;accuracy=0
# 732, xg=(16,22,24,22);wall_sink:False;accuracy=0.lat
# 733, xg=(16,24,44,31);wall_sink:True;accuracy=0
# 734, xg=(16,24,44,31);wall_sink:False;accuracy=0.lat
# 735, xg=(16,24,9,8);wall_sink:True;accuracy=0
# 736, xg=(16,24,9,8);wall_sink:False;accuracy=0.lat
# 737, xg=(16,27,40,20);wall_sink:True;accuracy=0
# 738, xg=(16,27,40,20);wall_sink:False;accuracy=0.lat
# 739, xg=(16,28,42,80);wall_sink:True;accuracy=0
# 740, xg=(16,28,42,80);wall_sink:False;accuracy=0.lat
# 741, xg=(16,29,23,30);wall_sink:True;accuracy=0
# 742, xg=(16,29,23,30);wall_sink:False;accuracy=0.lat
# 743, xg=(16,29,23,47);wall_sink:True;accuracy=0
# 744, xg=(16,29,23,47);wall_sink:False;accuracy=0.lat
# 745, xg=(16,29,3,8);wall_sink:True;accuracy=0
# 746, xg=(16,29,3,8);wall_sink:False;accuracy=0.lat
# 747, xg=(16,3,46,18);wall_sink:True;accuracy=0
# 748, xg=(16,3,46,18);wall_sink:False;accuracy=0.lat
# 749, xg=(16,30,21,27);wall_sink:True;accuracy=0
# 750, xg=(16,30,21,27);wall_sink:False;accuracy=0.lat
# 751, xg=(16,30,39,65);wall_sink:True;accuracy=0
# 752, xg=(16,30,39,65);wall_sink:False;accuracy=0.lat
# 753, xg=(16,31,41,66);wall_sink:True;accuracy=0
# 754, xg=(16,31,41,66);wall_sink:False;accuracy=0.lat
# 755, xg=(16,31,41,66);wall_sink:True;accuracy=1
# 756, xg=(16,31,41,66);wall_sink:False;accuracy=1.lat
# 757, xg=(16,31,9,6);wall_sink:True;accuracy=0
# 758, xg=(16,31,9,6);wall_sink:False;accuracy=0.lat
# 759, xg=(16,36,26,8);wall_sink:True;accuracy=0
# 760, xg=(16,36,26,8);wall_sink:False;accuracy=0.lat
# 761, xg=(16,37,5,48);wall_sink:True;accuracy=0
# 762, xg=(16,37,5,48);wall_sink:False;accuracy=0.lat
# 763, xg=(16,38,41,56);wall_sink:True;accuracy=0
# 764, xg=(16,38,41,56);wall_sink:False;accuracy=0.lat
# 765, xg=(16,4,21,94);wall_sink:True;accuracy=0
# 766, xg=(16,4,21,94);wall_sink:False;accuracy=0.lat
# 767, xg=(16,40,19,26);wall_sink:True;accuracy=0
# 768, xg=(16,40,19,26);wall_sink:False;accuracy=0.lat
# 769, xg=(16,40,7,51);wall_sink:True;accuracy=0
# 770, xg=(16,40,7,51);wall_sink:False;accuracy=0.lat
# 771, xg=(16,41,26,78);wall_sink:True;accuracy=0
# 772, xg=(16,41,26,78);wall_sink:False;accuracy=0.lat
# 773, xg=(16,42,17,46);wall_sink:True;accuracy=0
# 774, xg=(16,42,17,46);wall_sink:False;accuracy=0.lat
# 775, xg=(16,42,4,47);wall_sink:True;accuracy=0
# 776, xg=(16,42,4,47);wall_sink:False;accuracy=0.lat
# 777, xg=(16,45,1,62);wall_sink:True;accuracy=0
# 778, xg=(16,45,1,62);wall_sink:False;accuracy=0.lat
# 779, xg=(16,46,11,44);wall_sink:True;accuracy=0
# 780, xg=(16,46,11,44);wall_sink:False;accuracy=0.lat
# 781, xg=(16,5,23,33);wall_sink:True;accuracy=0
# 782, xg=(16,5,23,33);wall_sink:False;accuracy=0.lat
# 783, xg=(16,6,10,69);wall_sink:True;accuracy=0
# 784, xg=(16,6,10,69);wall_sink:False;accuracy=0.lat
# 785, xg=(16,6,32,95);wall_sink:True;accuracy=0
# 786, xg=(16,6,32,95);wall_sink:False;accuracy=0.lat
# 787, xg=(16,8,28,61);wall_sink:True;accuracy=0
# 788, xg=(16,8,28,61);wall_sink:False;accuracy=0.lat
# 789, xg=(16,8,7,14);wall_sink:True;accuracy=0
# 790, xg=(16,8,7,14);wall_sink:False;accuracy=0.lat
# 791, xg=(16,9,37,93);wall_sink:True;accuracy=0
# 792, xg=(16,9,37,93);wall_sink:False;accuracy=0.lat
# 793, xg=(17,0,17,39);wall_sink:True;accuracy=0
# 794, xg=(17,0,17,39);wall_sink:False;accuracy=0.lat
# 795, xg=(17,11,17,63);wall_sink:True;accuracy=0
# 796, xg=(17,11,17,63);wall_sink:False;accuracy=0.lat
# 797, xg=(17,11,26,93);wall_sink:True;accuracy=0
# 798, xg=(17,11,26,93);wall_sink:False;accuracy=0.lat
# 799, xg=(17,12,43,82);wall_sink:True;accuracy=0
# 800, xg=(17,12,43,82);wall_sink:False;accuracy=0.lat
# 801, xg=(17,15,27,31);wall_sink:True;accuracy=0
# 802, xg=(17,15,27,31);wall_sink:False;accuracy=0.lat
# 803, xg=(17,16,11,58);wall_sink:True;accuracy=0
# 804, xg=(17,16,11,58);wall_sink:False;accuracy=0.lat
# 805, xg=(17,16,9,55);wall_sink:True;accuracy=0
# 806, xg=(17,16,9,55);wall_sink:False;accuracy=0.lat
# 807, xg=(17,18,4,88);wall_sink:True;accuracy=0
# 808, xg=(17,18,4,88);wall_sink:False;accuracy=0.lat
# 809, xg=(17,2,29,8);wall_sink:True;accuracy=0
# 810, xg=(17,2,29,8);wall_sink:False;accuracy=0.lat
# 811, xg=(17,20,22,91);wall_sink:True;accuracy=0
# 812, xg=(17,20,22,91);wall_sink:False;accuracy=0.lat
# 813, xg=(17,21,24,39);wall_sink:True;accuracy=0
# 814, xg=(17,21,24,39);wall_sink:False;accuracy=0.lat
# 815, xg=(17,22,18,79);wall_sink:True;accuracy=0
# 816, xg=(17,22,18,79);wall_sink:False;accuracy=0.lat
# 817, xg=(17,22,27,56);wall_sink:True;accuracy=0
# 818, xg=(17,22,27,56);wall_sink:False;accuracy=0.lat
# 819, xg=(17,22,8,36);wall_sink:True;accuracy=0
# 820, xg=(17,22,8,36);wall_sink:False;accuracy=0.lat
# 821, xg=(17,23,20,51);wall_sink:True;accuracy=0
# 822, xg=(17,23,20,51);wall_sink:False;accuracy=0.lat
# 823, xg=(17,23,9,18);wall_sink:True;accuracy=0
# 824, xg=(17,23,9,18);wall_sink:False;accuracy=0.lat
# 825, xg=(17,24,0,25);wall_sink:True;accuracy=0
# 826, xg=(17,24,0,25);wall_sink:False;accuracy=0.lat
# 827, xg=(17,25,1,28);wall_sink:True;accuracy=0
# 828, xg=(17,25,1,28);wall_sink:False;accuracy=0.lat
# 829, xg=(17,25,33,39);wall_sink:True;accuracy=0
# 830, xg=(17,25,33,39);wall_sink:False;accuracy=0.lat
# 831, xg=(17,29,18,62);wall_sink:True;accuracy=0
# 832, xg=(17,29,18,62);wall_sink:False;accuracy=0.lat
# 833, xg=(17,29,18,62);wall_sink:True;accuracy=1
# 834, xg=(17,29,18,62);wall_sink:False;accuracy=1.lat
# 835, xg=(17,29,18,62);wall_sink:True;accuracy=2
# 836, xg=(17,29,18,62);wall_sink:False;accuracy=2.lat
# 837, xg=(17,31,30,73);wall_sink:True;accuracy=0
# 838, xg=(17,31,30,73);wall_sink:False;accuracy=0.lat
# 839, xg=(17,31,47,57);wall_sink:True;accuracy=0
# 840, xg=(17,31,47,57);wall_sink:False;accuracy=0.lat
# 841, xg=(17,32,41,71);wall_sink:True;accuracy=0
# 842, xg=(17,32,41,71);wall_sink:False;accuracy=0.lat
# 843, xg=(17,32,41,71);wall_sink:True;accuracy=1
# 844, xg=(17,32,41,71);wall_sink:False;accuracy=1.lat
# 845, xg=(17,34,13,49);wall_sink:True;accuracy=0
# 846, xg=(17,34,13,49);wall_sink:False;accuracy=0.lat
# 847, xg=(17,35,40,15);wall_sink:True;accuracy=0
# 848, xg=(17,35,40,15);wall_sink:False;accuracy=0.lat
# 849, xg=(17,36,28,34);wall_sink:True;accuracy=0
# 850, xg=(17,36,28,34);wall_sink:False;accuracy=0.lat
# 851, xg=(17,36,43,53);wall_sink:True;accuracy=0
# 852, xg=(17,36,43,53);wall_sink:False;accuracy=0.lat
# 853, xg=(17,37,43,11);wall_sink:True;accuracy=0
# 854, xg=(17,37,43,11);wall_sink:False;accuracy=0.lat
# 855, xg=(17,39,24,30);wall_sink:True;accuracy=0
# 856, xg=(17,39,24,30);wall_sink:False;accuracy=0.lat
# 857, xg=(17,39,44,0);wall_sink:True;accuracy=0
# 858, xg=(17,39,44,0);wall_sink:False;accuracy=0.lat
# 859, xg=(17,41,11,59);wall_sink:True;accuracy=0
# 860, xg=(17,41,11,59);wall_sink:False;accuracy=0.lat
# 861, xg=(17,41,2,5);wall_sink:True;accuracy=0
# 862, xg=(17,41,2,5);wall_sink:False;accuracy=0.lat
# 863, xg=(17,42,18,47);wall_sink:True;accuracy=0
# 864, xg=(17,42,18,47);wall_sink:False;accuracy=0.lat
# 865, xg=(17,42,9,41);wall_sink:True;accuracy=0
# 866, xg=(17,42,9,41);wall_sink:False;accuracy=0.lat
# 867, xg=(17,44,0,4);wall_sink:True;accuracy=0
# 868, xg=(17,44,0,4);wall_sink:False;accuracy=0.lat
# 869, xg=(17,46,2,59);wall_sink:True;accuracy=0
# 870, xg=(17,46,2,59);wall_sink:False;accuracy=0.lat
# 871, xg=(17,47,16,21);wall_sink:True;accuracy=0
# 872, xg=(17,47,16,21);wall_sink:False;accuracy=0.lat
# 873, xg=(17,47,16,21);wall_sink:True;accuracy=1
# 874, xg=(17,47,16,21);wall_sink:False;accuracy=1.lat
# 875, xg=(17,47,34,13);wall_sink:True;accuracy=0
# 876, xg=(17,47,34,13);wall_sink:False;accuracy=0.lat
# 877, xg=(17,5,11,18);wall_sink:True;accuracy=0
# 878, xg=(17,5,11,18);wall_sink:False;accuracy=0.lat
# 879, xg=(17,7,28,46);wall_sink:True;accuracy=0
# 880, xg=(17,7,28,46);wall_sink:False;accuracy=0.lat
# 881, xg=(17,9,32,17);wall_sink:True;accuracy=0
# 882, xg=(17,9,32,17);wall_sink:False;accuracy=0.lat
# 883, xg=(17,9,41,25);wall_sink:True;accuracy=0
# 884, xg=(17,9,41,25);wall_sink:False;accuracy=0.lat
# 885, xg=(18,0,2,61);wall_sink:True;accuracy=0
# 886, xg=(18,0,2,61);wall_sink:False;accuracy=0.lat
# 887, xg=(18,0,24,35);wall_sink:True;accuracy=0
# 888, xg=(18,0,24,35);wall_sink:False;accuracy=0.lat
# 889, xg=(18,1,9,91);wall_sink:True;accuracy=0
# 890, xg=(18,1,9,91);wall_sink:False;accuracy=0.lat
# 891, xg=(18,10,0,49);wall_sink:True;accuracy=0
# 892, xg=(18,10,0,49);wall_sink:False;accuracy=0.lat
# 893, xg=(18,10,45,12);wall_sink:True;accuracy=0
# 894, xg=(18,10,45,12);wall_sink:False;accuracy=0.lat
# 895, xg=(18,13,27,5);wall_sink:True;accuracy=0
# 896, xg=(18,13,27,5);wall_sink:False;accuracy=0.lat
# 897, xg=(18,15,16,64);wall_sink:True;accuracy=0
# 898, xg=(18,15,16,64);wall_sink:False;accuracy=0.lat
# 899, xg=(18,15,21,30);wall_sink:True;accuracy=0
# 900, xg=(18,15,21,30);wall_sink:False;accuracy=0.lat
# 901, xg=(18,15,28,4);wall_sink:True;accuracy=0
# 902, xg=(18,15,28,4);wall_sink:False;accuracy=0.lat
# 903, xg=(18,18,41,58);wall_sink:True;accuracy=0
# 904, xg=(18,18,41,58);wall_sink:False;accuracy=0.lat
# 905, xg=(18,19,44,39);wall_sink:True;accuracy=0
# 906, xg=(18,19,44,39);wall_sink:False;accuracy=0.lat
# 907, xg=(18,2,30,10);wall_sink:True;accuracy=0
# 908, xg=(18,2,30,10);wall_sink:False;accuracy=0.lat
# 909, xg=(18,21,14,18);wall_sink:True;accuracy=0
# 910, xg=(18,21,14,18);wall_sink:False;accuracy=0.lat
# 911, xg=(18,22,33,27);wall_sink:True;accuracy=0
# 912, xg=(18,22,33,27);wall_sink:False;accuracy=0.lat
# 913, xg=(18,22,39,20);wall_sink:True;accuracy=0
# 914, xg=(18,22,39,20);wall_sink:False;accuracy=0.lat
# 915, xg=(18,23,22,70);wall_sink:True;accuracy=0
# 916, xg=(18,23,22,70);wall_sink:False;accuracy=0.lat
# 917, xg=(18,24,31,67);wall_sink:True;accuracy=0
# 918, xg=(18,24,31,67);wall_sink:False;accuracy=0.lat
# 919, xg=(18,24,36,11);wall_sink:True;accuracy=0
# 920, xg=(18,24,36,11);wall_sink:False;accuracy=0.lat
# 921, xg=(18,26,20,92);wall_sink:True;accuracy=0
# 922, xg=(18,26,20,92);wall_sink:False;accuracy=0.lat
# 923, xg=(18,26,8,3);wall_sink:True;accuracy=0
# 924, xg=(18,26,8,3);wall_sink:False;accuracy=0.lat
# 925, xg=(18,28,25,2);wall_sink:True;accuracy=0
# 926, xg=(18,28,25,2);wall_sink:False;accuracy=0.lat
# 927, xg=(18,28,38,69);wall_sink:True;accuracy=0
# 928, xg=(18,28,38,69);wall_sink:False;accuracy=0.lat
# 929, xg=(18,30,2,70);wall_sink:True;accuracy=0
# 930, xg=(18,30,2,70);wall_sink:False;accuracy=0.lat
# 931, xg=(18,30,40,55);wall_sink:True;accuracy=0
# 932, xg=(18,30,40,55);wall_sink:False;accuracy=0.lat
# 933, xg=(18,30,40,55);wall_sink:True;accuracy=1
# 934, xg=(18,30,40,55);wall_sink:False;accuracy=1.lat
# 935, xg=(18,30,45,65);wall_sink:True;accuracy=0
# 936, xg=(18,30,45,65);wall_sink:False;accuracy=0.lat
# 937, xg=(18,30,47,67);wall_sink:True;accuracy=0
# 938, xg=(18,30,47,67);wall_sink:False;accuracy=0.lat
# 939, xg=(18,31,24,3);wall_sink:True;accuracy=0
# 940, xg=(18,31,24,3);wall_sink:False;accuracy=0.lat
# 941, xg=(18,32,11,94);wall_sink:True;accuracy=0
# 942, xg=(18,32,11,94);wall_sink:False;accuracy=0.lat
# 943, xg=(18,33,17,70);wall_sink:True;accuracy=0
# 944, xg=(18,33,17,70);wall_sink:False;accuracy=0.lat
# 945, xg=(18,33,19,48);wall_sink:True;accuracy=0
# 946, xg=(18,33,19,48);wall_sink:False;accuracy=0.lat
# 947, xg=(18,35,6,21);wall_sink:True;accuracy=0
# 948, xg=(18,35,6,21);wall_sink:False;accuracy=0.lat
# 949, xg=(18,36,45,79);wall_sink:True;accuracy=0
# 950, xg=(18,36,45,79);wall_sink:False;accuracy=0.lat
# 951, xg=(18,37,45,80);wall_sink:True;accuracy=0
# 952, xg=(18,37,45,80);wall_sink:False;accuracy=0.lat
# 953, xg=(18,37,7,50);wall_sink:True;accuracy=0
# 954, xg=(18,37,7,50);wall_sink:False;accuracy=0.lat
# 955, xg=(18,38,29,8);wall_sink:True;accuracy=0
# 956, xg=(18,38,29,8);wall_sink:False;accuracy=0.lat
# 957, xg=(18,39,27,64);wall_sink:True;accuracy=0
# 958, xg=(18,39,27,64);wall_sink:False;accuracy=0.lat
# 959, xg=(18,46,30,44);wall_sink:True;accuracy=0
# 960, xg=(18,46,30,44);wall_sink:False;accuracy=0.lat
# 961, xg=(18,5,29,52);wall_sink:True;accuracy=0
# 962, xg=(18,5,29,52);wall_sink:False;accuracy=0.lat
# 963, xg=(18,6,18,59);wall_sink:True;accuracy=0
# 964, xg=(18,6,18,59);wall_sink:False;accuracy=0.lat
# ...
# 3937, xg=(6,22,5,80);wall_sink:True;accuracy=0
# 3938, xg=(6,22,5,80);wall_sink:False;accuracy=0.lat
# 3939, xg=(6,23,22,46);wall_sink:True;accuracy=0
# 3940, xg=(6,23,22,46);wall_sink:False;accuracy=0.lat
# 3941, xg=(6,23,35,29);wall_sink:True;accuracy=0
# 3942, xg=(6,23,35,29);wall_sink:False;accuracy=0.lat
# 3943, xg=(6,24,20,74);wall_sink:True;accuracy=0
# 3944, xg=(6,24,20,74);wall_sink:False;accuracy=0.lat
# 3945, xg=(6,24,35,86);wall_sink:True;accuracy=0
# 3946, xg=(6,24,35,86);wall_sink:False;accuracy=0.lat
# 3947, xg=(6,25,21,8);wall_sink:True;accuracy=0
# 3948, xg=(6,25,21,8);wall_sink:False;accuracy=0.lat
# 3949, xg=(6,28,37,14);wall_sink:True;accuracy=0
# 3950, xg=(6,28,37,14);wall_sink:False;accuracy=0.lat
# 3951, xg=(6,29,42,61);wall_sink:True;accuracy=0
# 3952, xg=(6,29,42,61);wall_sink:False;accuracy=0.lat
# 3953, xg=(6,35,18,45);wall_sink:True;accuracy=0
# 3954, xg=(6,35,18,45);wall_sink:False;accuracy=0.lat
# 3955, xg=(6,35,40,34);wall_sink:True;accuracy=0
# 3956, xg=(6,35,40,34);wall_sink:False;accuracy=0.lat
# 3957, xg=(6,36,42,92);wall_sink:True;accuracy=0
# 3958, xg=(6,36,42,92);wall_sink:False;accuracy=0.lat
# 3959, xg=(6,37,33,28);wall_sink:True;accuracy=0
# 3960, xg=(6,37,33,28);wall_sink:False;accuracy=0.lat
# 3961, xg=(6,4,12,52);wall_sink:True;accuracy=0
# 3962, xg=(6,4,12,52);wall_sink:False;accuracy=0.lat
# 3963, xg=(6,4,3,48);wall_sink:True;accuracy=0
# 3964, xg=(6,4,3,48);wall_sink:False;accuracy=0.lat
# 3965, xg=(6,4,39,2);wall_sink:True;accuracy=0
# 3966, xg=(6,4,39,2);wall_sink:False;accuracy=0.lat
# 3967, xg=(6,40,31,0);wall_sink:True;accuracy=0
# 3968, xg=(6,40,31,0);wall_sink:False;accuracy=0.lat
# 3969, xg=(6,40,37,64);wall_sink:True;accuracy=0
# 3970, xg=(6,40,37,64);wall_sink:False;accuracy=0.lat
# 3971, xg=(6,40,6,27);wall_sink:True;accuracy=0
# 3972, xg=(6,40,6,27);wall_sink:False;accuracy=0.lat
# 3973, xg=(6,41,24,65);wall_sink:True;accuracy=0
# 3974, xg=(6,41,24,65);wall_sink:False;accuracy=0.lat
# 3975, xg=(6,41,32,86);wall_sink:True;accuracy=0
# 3976, xg=(6,41,32,86);wall_sink:False;accuracy=0.lat
# 3977, xg=(6,41,38,77);wall_sink:True;accuracy=0
# 3978, xg=(6,41,38,77);wall_sink:False;accuracy=0.lat
# 3979, xg=(6,42,41,66);wall_sink:True;accuracy=0
# 3980, xg=(6,42,41,66);wall_sink:False;accuracy=0.lat
# 3981, xg=(6,46,7,75);wall_sink:True;accuracy=0
# 3982, xg=(6,46,7,75);wall_sink:False;accuracy=0.lat
# 3983, xg=(6,47,1,69);wall_sink:True;accuracy=0
# 3984, xg=(6,47,1,69);wall_sink:False;accuracy=0.lat
# 3985, xg=(6,5,15,85);wall_sink:True;accuracy=0
# 3986, xg=(6,5,15,85);wall_sink:False;accuracy=0.lat
# 3987, xg=(6,5,18,93);wall_sink:True;accuracy=0
# 3988, xg=(6,5,18,93);wall_sink:False;accuracy=0.lat
# 3989, xg=(6,5,38,56);wall_sink:True;accuracy=0
# 3990, xg=(6,5,38,56);wall_sink:False;accuracy=0.lat
# 3991, xg=(6,6,22,73);wall_sink:True;accuracy=0
# 3992, xg=(6,6,22,73);wall_sink:False;accuracy=0.lat
# 3993, xg=(6,7,11,6);wall_sink:True;accuracy=0
# 3994, xg=(6,7,11,6);wall_sink:False;accuracy=0.lat
# 3995, xg=(6,8,23,51);wall_sink:True;accuracy=0
# 3996, xg=(6,8,23,51);wall_sink:False;accuracy=0.lat
# 3997, xg=(6,9,25,48);wall_sink:True;accuracy=0
# 3998, xg=(6,9,25,48);wall_sink:False;accuracy=0.lat
# 3999, xg=(7,0,0,3);wall_sink:True;accuracy=0
# 4000, xg=(7,0,0,3);wall_sink:False;accuracy=0.lat
# 4001, xg=(7,10,37,25);wall_sink:True;accuracy=0
# 4002, xg=(7,10,37,25);wall_sink:False;accuracy=0.lat
# 4003, xg=(7,13,29,61);wall_sink:True;accuracy=0
# 4004, xg=(7,13,29,61);wall_sink:False;accuracy=0.lat
# 4005, xg=(7,14,26,37);wall_sink:True;accuracy=0
# 4006, xg=(7,14,26,37);wall_sink:False;accuracy=0.lat
# 4007, xg=(7,16,38,63);wall_sink:True;accuracy=0
# 4008, xg=(7,16,38,63);wall_sink:False;accuracy=0.lat
# 4009, xg=(7,2,0,60);wall_sink:True;accuracy=0
# 4010, xg=(7,2,0,60);wall_sink:False;accuracy=0.lat
# 4011, xg=(7,2,10,75);wall_sink:True;accuracy=0
# 4012, xg=(7,2,10,75);wall_sink:False;accuracy=0.lat
# 4013, xg=(7,2,11,86);wall_sink:True;accuracy=0
# 4014, xg=(7,2,11,86);wall_sink:False;accuracy=0.lat
# 4015, xg=(7,2,33,88);wall_sink:True;accuracy=0
# 4016, xg=(7,2,33,88);wall_sink:False;accuracy=0.lat
# 4017, xg=(7,2,37,86);wall_sink:True;accuracy=0
# 4018, xg=(7,2,37,86);wall_sink:False;accuracy=0.lat
# 4019, xg=(7,2,45,30);wall_sink:True;accuracy=0
# 4020, xg=(7,2,45,30);wall_sink:False;accuracy=0.lat
# 4021, xg=(7,20,14,40);wall_sink:True;accuracy=0
# 4022, xg=(7,20,14,40);wall_sink:False;accuracy=0.lat
# 4023, xg=(7,20,6,31);wall_sink:True;accuracy=0
# 4024, xg=(7,20,6,31);wall_sink:False;accuracy=0.lat
# 4025, xg=(7,20,8,3);wall_sink:True;accuracy=0
# 4026, xg=(7,20,8,3);wall_sink:False;accuracy=0.lat
# 4027, xg=(7,21,31,17);wall_sink:True;accuracy=0
# 4028, xg=(7,21,31,17);wall_sink:False;accuracy=0.lat
# 4029, xg=(7,22,16,11);wall_sink:True;accuracy=0
# 4030, xg=(7,22,16,11);wall_sink:False;accuracy=0.lat
# 4031, xg=(7,22,16,11);wall_sink:True;accuracy=1
# 4032, xg=(7,22,16,11);wall_sink:False;accuracy=1.lat
# 4033, xg=(7,22,16,11);wall_sink:True;accuracy=2
# 4034, xg=(7,22,16,11);wall_sink:False;accuracy=2.lat
# 4035, xg=(7,22,39,33);wall_sink:True;accuracy=0
# 4036, xg=(7,22,39,33);wall_sink:False;accuracy=0.lat
# 4037, xg=(7,23,39,86);wall_sink:True;accuracy=0
# 4038, xg=(7,23,39,86);wall_sink:False;accuracy=0.lat
# 4039, xg=(7,24,24,78);wall_sink:True;accuracy=0
# 4040, xg=(7,24,24,78);wall_sink:False;accuracy=0.lat
# 4041, xg=(7,25,18,35);wall_sink:True;accuracy=0
# 4042, xg=(7,25,18,35);wall_sink:False;accuracy=0.lat
# 4043, xg=(7,26,44,88);wall_sink:True;accuracy=0
# 4044, xg=(7,26,44,88);wall_sink:False;accuracy=0.lat
# 4045, xg=(7,28,18,10);wall_sink:True;accuracy=0
# 4046, xg=(7,28,18,10);wall_sink:False;accuracy=0.lat
# 4047, xg=(7,3,4,19);wall_sink:True;accuracy=0
# 4048, xg=(7,3,4,19);wall_sink:False;accuracy=0.lat
# 4049, xg=(7,3,41,65);wall_sink:True;accuracy=0
# 4050, xg=(7,3,41,65);wall_sink:False;accuracy=0.lat
# 4051, xg=(7,30,26,91);wall_sink:True;accuracy=0
# 4052, xg=(7,30,26,91);wall_sink:False;accuracy=0.lat
# 4053, xg=(7,30,44,49);wall_sink:True;accuracy=0
# 4054, xg=(7,30,44,49);wall_sink:False;accuracy=0.lat
# 4055, xg=(7,31,2,15);wall_sink:True;accuracy=0
# 4056, xg=(7,31,2,15);wall_sink:False;accuracy=0.lat
# 4057, xg=(7,31,8,63);wall_sink:True;accuracy=0
# 4058, xg=(7,31,8,63);wall_sink:False;accuracy=0.lat
# 4059, xg=(7,32,23,4);wall_sink:True;accuracy=0
# 4060, xg=(7,32,23,4);wall_sink:False;accuracy=0.lat
# 4061, xg=(7,32,32,60);wall_sink:True;accuracy=0
# 4062, xg=(7,32,32,60);wall_sink:False;accuracy=0.lat
# 4063, xg=(7,33,27,32);wall_sink:True;accuracy=0
# 4064, xg=(7,33,27,32);wall_sink:False;accuracy=0.lat
# 4065, xg=(7,33,8,91);wall_sink:True;accuracy=0
# 4066, xg=(7,33,8,91);wall_sink:False;accuracy=0.lat
# 4067, xg=(7,35,10,13);wall_sink:True;accuracy=0
# 4068, xg=(7,35,10,13);wall_sink:False;accuracy=0.lat
# 4069, xg=(7,35,47,58);wall_sink:True;accuracy=0
# 4070, xg=(7,35,47,58);wall_sink:False;accuracy=0.lat
# 4071, xg=(7,38,9,89);wall_sink:True;accuracy=0
# 4072, xg=(7,38,9,89);wall_sink:False;accuracy=0.lat
# 4073, xg=(7,39,25,14);wall_sink:True;accuracy=0
# 4074, xg=(7,39,25,14);wall_sink:False;accuracy=0.lat
# 4075, xg=(7,4,24,41);wall_sink:True;accuracy=0
# 4076, xg=(7,4,24,41);wall_sink:False;accuracy=0.lat
# 4077, xg=(7,4,27,54);wall_sink:True;accuracy=0
# 4078, xg=(7,4,27,54);wall_sink:False;accuracy=0.lat
# 4079, xg=(7,4,9,57);wall_sink:True;accuracy=0
# 4080, xg=(7,4,9,57);wall_sink:False;accuracy=0.lat
# 4081, xg=(7,40,0,15);wall_sink:True;accuracy=0
# 4082, xg=(7,40,0,15);wall_sink:False;accuracy=0.lat
# 4083, xg=(7,41,1,5);wall_sink:True;accuracy=0
# 4084, xg=(7,41,1,5);wall_sink:False;accuracy=0.lat
# 4085, xg=(7,42,27,69);wall_sink:True;accuracy=0
# 4086, xg=(7,42,27,69);wall_sink:False;accuracy=0.lat
# 4087, xg=(7,45,6,67);wall_sink:True;accuracy=0
# 4088, xg=(7,45,6,67);wall_sink:False;accuracy=0.lat
# 4089, xg=(7,46,43,31);wall_sink:True;accuracy=0
# 4090, xg=(7,46,43,31);wall_sink:False;accuracy=0.lat
# 4091, xg=(7,5,7,32);wall_sink:True;accuracy=0
# 4092, xg=(7,5,7,32);wall_sink:False;accuracy=0.lat
# 4093, xg=(7,8,42,26);wall_sink:True;accuracy=0
# 4094, xg=(7,8,42,26);wall_sink:False;accuracy=0.lat
# 4095, xg=(7,9,4,26);wall_sink:True;accuracy=0
# 4096, xg=(7,9,4,26);wall_sink:False;accuracy=0.lat
# 4097, xg=(8,0,23,46);wall_sink:True;accuracy=0
# 4098, xg=(8,0,23,46);wall_sink:False;accuracy=0.lat
# 4099, xg=(8,1,6,88);wall_sink:True;accuracy=0
# 4100, xg=(8,1,6,88);wall_sink:False;accuracy=0.lat
# 4101, xg=(8,12,26,66);wall_sink:True;accuracy=0
# 4102, xg=(8,12,26,66);wall_sink:False;accuracy=0.lat
# 4103, xg=(8,12,32,7);wall_sink:True;accuracy=0
# 4104, xg=(8,12,32,7);wall_sink:False;accuracy=0.lat
# 4105, xg=(8,14,11,17);wall_sink:True;accuracy=0
# 4106, xg=(8,14,11,17);wall_sink:False;accuracy=0.lat
# 4107, xg=(8,14,29,25);wall_sink:True;accuracy=0
# 4108, xg=(8,14,29,25);wall_sink:False;accuracy=0.lat
# 4109, xg=(8,14,29,25);wall_sink:True;accuracy=1
# 4110, xg=(8,14,29,25);wall_sink:False;accuracy=1.lat
# 4111, xg=(8,14,8,43);wall_sink:True;accuracy=0
# 4112, xg=(8,14,8,43);wall_sink:False;accuracy=0.lat
# 4113, xg=(8,15,17,40);wall_sink:True;accuracy=0
# 4114, xg=(8,15,17,40);wall_sink:False;accuracy=0.lat
# 4115, xg=(8,15,7,65);wall_sink:True;accuracy=0
# 4116, xg=(8,15,7,65);wall_sink:False;accuracy=0.lat
# 4117, xg=(8,15,8,26);wall_sink:True;accuracy=0
# 4118, xg=(8,15,8,26);wall_sink:False;accuracy=0.lat
# 4119, xg=(8,17,24,13);wall_sink:True;accuracy=0
# 4120, xg=(8,17,24,13);wall_sink:False;accuracy=0.lat
# 4121, xg=(8,18,38,36);wall_sink:True;accuracy=0
# 4122, xg=(8,18,38,36);wall_sink:False;accuracy=0.lat
# 4123, xg=(8,19,19,76);wall_sink:True;accuracy=0
# 4124, xg=(8,19,19,76);wall_sink:False;accuracy=0.lat
# 4125, xg=(8,19,41,78);wall_sink:True;accuracy=0
# 4126, xg=(8,19,41,78);wall_sink:False;accuracy=0.lat
# 4127, xg=(8,2,46,44);wall_sink:True;accuracy=0
# 4128, xg=(8,2,46,44);wall_sink:False;accuracy=0.lat
# 4129, xg=(8,2,7,89);wall_sink:True;accuracy=0
# 4130, xg=(8,2,7,89);wall_sink:False;accuracy=0.lat
# 4131, xg=(8,22,12,78);wall_sink:True;accuracy=0
# 4132, xg=(8,22,12,78);wall_sink:False;accuracy=0.lat
# 4133, xg=(8,22,6,32);wall_sink:True;accuracy=0
# 4134, xg=(8,22,6,32);wall_sink:False;accuracy=0.lat
# 4135, xg=(8,23,37,35);wall_sink:True;accuracy=0
# 4136, xg=(8,23,37,35);wall_sink:False;accuracy=0.lat
# 4137, xg=(8,25,17,44);wall_sink:True;accuracy=0
# 4138, xg=(8,25,17,44);wall_sink:False;accuracy=0.lat
# 4139, xg=(8,25,38,26);wall_sink:True;accuracy=0
# 4140, xg=(8,25,38,26);wall_sink:False;accuracy=0.lat
# 4141, xg=(8,25,38,26);wall_sink:True;accuracy=1
# 4142, xg=(8,25,38,26);wall_sink:False;accuracy=1.lat
# 4143, xg=(8,28,39,21);wall_sink:True;accuracy=0
# 4144, xg=(8,28,39,21);wall_sink:False;accuracy=0.lat
# 4145, xg=(8,29,43,58);wall_sink:True;accuracy=0
# 4146, xg=(8,29,43,58);wall_sink:False;accuracy=0.lat
# 4147, xg=(8,30,4,78);wall_sink:True;accuracy=0
# 4148, xg=(8,30,4,78);wall_sink:False;accuracy=0.lat
# 4149, xg=(8,31,44,94);wall_sink:True;accuracy=0
# 4150, xg=(8,31,44,94);wall_sink:False;accuracy=0.lat
# 4151, xg=(8,34,8,7);wall_sink:True;accuracy=0
# 4152, xg=(8,34,8,7);wall_sink:False;accuracy=0.lat
# 4153, xg=(8,36,14,72);wall_sink:True;accuracy=0
# 4154, xg=(8,36,14,72);wall_sink:False;accuracy=0.lat
# 4155, xg=(8,39,22,30);wall_sink:True;accuracy=0
# 4156, xg=(8,39,22,30);wall_sink:False;accuracy=0.lat
# 4157, xg=(8,4,24,33);wall_sink:True;accuracy=0
# 4158, xg=(8,4,24,33);wall_sink:False;accuracy=0.lat
# 4159, xg=(8,4,33,4);wall_sink:True;accuracy=0
# 4160, xg=(8,4,33,4);wall_sink:False;accuracy=0.lat
# 4161, xg=(8,4,34,57);wall_sink:True;accuracy=0
# 4162, xg=(8,4,34,57);wall_sink:False;accuracy=0.lat
# 4163, xg=(8,41,22,20);wall_sink:True;accuracy=0
# 4164, xg=(8,41,22,20);wall_sink:False;accuracy=0.lat
# 4165, xg=(8,44,29,51);wall_sink:True;accuracy=0
# 4166, xg=(8,44,29,51);wall_sink:False;accuracy=0.lat
# 4167, xg=(8,45,33,23);wall_sink:True;accuracy=0
# 4168, xg=(8,45,33,23);wall_sink:False;accuracy=0.lat
# 4169, xg=(8,45,47,52);wall_sink:True;accuracy=0
# 4170, xg=(8,45,47,52);wall_sink:False;accuracy=0.lat
# 4171, xg=(8,47,3,44);wall_sink:True;accuracy=0
# 4172, xg=(8,47,3,44);wall_sink:False;accuracy=0.lat
# 4173, xg=(8,7,17,49);wall_sink:True;accuracy=0
# 4174, xg=(8,7,17,49);wall_sink:False;accuracy=0.lat
# 4175, xg=(9,0,16,21);wall_sink:True;accuracy=0
# 4176, xg=(9,0,16,21);wall_sink:False;accuracy=0.lat
# 4177, xg=(9,0,6,12);wall_sink:True;accuracy=0
# 4178, xg=(9,0,6,12);wall_sink:False;accuracy=0.lat
# 4179, xg=(9,1,35,50);wall_sink:True;accuracy=0
# 4180, xg=(9,1,35,50);wall_sink:False;accuracy=0.lat
# 4181, xg=(9,1,43,20);wall_sink:True;accuracy=0
# 4182, xg=(9,1,43,20);wall_sink:False;accuracy=0.lat
# 4183, xg=(9,1,43,20);wall_sink:True;accuracy=1
# 4184, xg=(9,1,43,20);wall_sink:False;accuracy=1.lat
# 4185, xg=(9,10,27,15);wall_sink:True;accuracy=0
# 4186, xg=(9,10,27,15);wall_sink:False;accuracy=0.lat
# 4187, xg=(9,10,35,42);wall_sink:True;accuracy=0
# 4188, xg=(9,10,35,42);wall_sink:False;accuracy=0.lat
# 4189, xg=(9,11,43,88);wall_sink:True;accuracy=0
# 4190, xg=(9,11,43,88);wall_sink:False;accuracy=0.lat
# 4191, xg=(9,12,5,55);wall_sink:True;accuracy=0
# 4192, xg=(9,12,5,55);wall_sink:False;accuracy=0.lat
# 4193, xg=(9,12,5,55);wall_sink:True;accuracy=1
# 4194, xg=(9,12,5,55);wall_sink:False;accuracy=1.lat
# 4195, xg=(9,14,17,85);wall_sink:True;accuracy=0
# 4196, xg=(9,14,17,85);wall_sink:False;accuracy=0.lat
# 4197, xg=(9,14,20,10);wall_sink:True;accuracy=0
# 4198, xg=(9,14,20,10);wall_sink:False;accuracy=0.lat
# 4199, xg=(9,14,6,31);wall_sink:True;accuracy=0
# 4200, xg=(9,14,6,31);wall_sink:False;accuracy=0.lat
# 4201, xg=(9,16,36,62);wall_sink:True;accuracy=0
# 4202, xg=(9,16,36,62);wall_sink:False;accuracy=0.lat
# 4203, xg=(9,18,24,56);wall_sink:True;accuracy=0
# 4204, xg=(9,18,24,56);wall_sink:False;accuracy=0.lat
# 4205, xg=(9,19,42,7);wall_sink:True;accuracy=0
# 4206, xg=(9,19,42,7);wall_sink:False;accuracy=0.lat
# 4207, xg=(9,2,24,29);wall_sink:True;accuracy=0
# 4208, xg=(9,2,24,29);wall_sink:False;accuracy=0.lat
# 4209, xg=(9,2,31,87);wall_sink:True;accuracy=0
# 4210, xg=(9,2,31,87);wall_sink:False;accuracy=0.lat
# 4211, xg=(9,20,41,78);wall_sink:True;accuracy=0
# 4212, xg=(9,20,41,78);wall_sink:False;accuracy=0.lat
# 4213, xg=(9,22,43,38);wall_sink:True;accuracy=0
# 4214, xg=(9,22,43,38);wall_sink:False;accuracy=0.lat
# 4215, xg=(9,28,39,52);wall_sink:True;accuracy=0
# 4216, xg=(9,28,39,52);wall_sink:False;accuracy=0.lat
# 4217, xg=(9,28,39,52);wall_sink:True;accuracy=1
# 4218, xg=(9,28,39,52);wall_sink:False;accuracy=1.lat
# 4219, xg=(9,28,39,67);wall_sink:True;accuracy=0
# 4220, xg=(9,28,39,67);wall_sink:False;accuracy=0.lat
# 4221, xg=(9,29,40,79);wall_sink:True;accuracy=0
# 4222, xg=(9,29,40,79);wall_sink:False;accuracy=0.lat
# 4223, xg=(9,30,27,40);wall_sink:True;accuracy=0
# 4224, xg=(9,30,27,40);wall_sink:False;accuracy=0.lat
# 4225, xg=(9,32,23,53);wall_sink:True;accuracy=0
# 4226, xg=(9,32,23,53);wall_sink:False;accuracy=0.lat
# 4227, xg=(9,33,28,81);wall_sink:True;accuracy=0
# 4228, xg=(9,33,28,81);wall_sink:False;accuracy=0.lat
# 4229, xg=(9,35,21,76);wall_sink:True;accuracy=0
# 4230, xg=(9,35,21,76);wall_sink:False;accuracy=0.lat
# 4231, xg=(9,39,37,77);wall_sink:True;accuracy=0
# 4232, xg=(9,39,37,77);wall_sink:False;accuracy=0.lat
# 4233, xg=(9,4,38,80);wall_sink:True;accuracy=0
# 4234, xg=(9,4,38,80);wall_sink:False;accuracy=0.lat
# 4235, xg=(9,40,23,87);wall_sink:True;accuracy=0
# 4236, xg=(9,40,23,87);wall_sink:False;accuracy=0.lat
# 4237, xg=(9,40,28,20);wall_sink:True;accuracy=0
# 4238, xg=(9,40,28,20);wall_sink:False;accuracy=0.lat
# 4239, xg=(9,41,41,78);wall_sink:True;accuracy=0
# 4240, xg=(9,41,41,78);wall_sink:False;accuracy=0.lat
# 4241, xg=(9,42,2,36);wall_sink:True;accuracy=0
# 4242, xg=(9,42,2,36);wall_sink:False;accuracy=0.lat
# 4243, xg=(9,45,13,61);wall_sink:True;accuracy=0
# 4244, xg=(9,45,13,61);wall_sink:False;accuracy=0.lat
# 4245, xg=(9,45,45,2);wall_sink:True;accuracy=0
# 4246, xg=(9,45,45,2);wall_sink:False;accuracy=0.lat
# 4247, xg=(9,47,46,68);wall_sink:True;accuracy=0
# 4248, xg=(9,47,46,68);wall_sink:False;accuracy=0.lat
# 4249, xg=(9,5,39,73);wall_sink:True;accuracy=0
# 4250, xg=(9,5,39,73);wall_sink:False;accuracy=0.lat
# 4251, xg=(9,7,8,91);wall_sink:True;accuracy=0
# 4252, xg=(9,7,8,91);wall_sink:False;accuracy=0.lat
# 4253, xg=(9,9,32,35);wall_sink:True;accuracy=0
# 4254, xg=(9,9,32,35);wall_sink:False;accuracy=0.lat
# 4255, xg=(9,9,32,35);wall_sink:True;accuracy=1
# 4256, xg=(9,9,32,35);wall_sink:False;accuracy=1.lat

# %%
if len(q_idx.prop_offsets) == 0:
    print(f"dictionary is not populated")
# Out:
# dictionary is not populated

# %%
q = qar_prop_io(fn_idx)

# %%
q.read_header()
# Out:
# GPT :    6173.384978 s : Qlattice file format; reading /data1/qcddata2/48I/psel-prop-psrc-light/traj-1122.qar.idx
# GPT :    6173.385459 s :    #!/usr/bin/env qar-idx-glimpse
# GPT :    6173.385877 s :
# GPT :    6173.386299 s : 	QAR-FILE-IDX 0 0 14
# GPT :    6173.386638 s : 	checkpoint.txt
# GPT :    6173.386994 s : 	28 44 59 60 62 14 0 0
# GPT :    6173.387357 s :
# GPT :    6173.387684 s : 	QAR-FILE-IDX 0 1 47
# GPT :    6173.388013 s : 	xg=(0,1,38,62) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.388418 s : 	62 83 131 132 221451 47 0 221317
# GPT :    6173.388788 s :
# GPT :    6173.389111 s : 	QAR-FILE-IDX 0 2 40
# GPT :    6173.389495 s : 	xg=(0,1,38,62) ; type=0 ; accuracy=0.lat
# GPT :    6173.389833 s : 	221451 221473 221514 221515 4940245 40 0 4718728
# GPT :    6173.390129 s :
# GPT :    6173.390503 s : 	QAR-FILE-IDX 0 3 47
# GPT :    6173.390819 s : 	xg=(0,1,38,62) ; type=0 ; accuracy=1 ; wsnk.lat
# GPT :    6173.391165 s : 	4940245 4940266 4940314 4940315 5161634 47 0 221317
# GPT :    6173.391508 s :
# GPT :    6173.391800 s : 	QAR-FILE-IDX 0 4 40
# GPT :    6173.392085 s : 	xg=(0,1,38,62) ; type=0 ; accuracy=1.lat
# GPT :    6173.392367 s : 	5161634 5161656 5161697 5161698 9880428 40 0 4718728
# GPT :    6173.392649 s :
# GPT :    6173.392934 s : 	QAR-FILE-IDX 0 5 48
# GPT :    6173.393226 s : 	xg=(0,15,25,38) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.393505 s : 	9880428 9880449 9880498 9880499 10101818 48 0 221317
# GPT :    6173.393773 s :
# GPT :    6173.394053 s : 	QAR-FILE-IDX 0 6 41
# GPT :    6173.394317 s : 	xg=(0,15,25,38) ; type=0 ; accuracy=0.lat
# GPT :    6173.394641 s : 	10101818 10101840 10101882 10101883 14820613 41 0 4718728
# GPT :    6173.394942 s :
# GPT :    6173.395240 s : 	QAR-FILE-IDX 0 7 48
# GPT :    6173.395528 s : 	xg=(0,16,24,84) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.395835 s : 	14820613 14820634 14820683 14820684 15042003 48 0 221317
# GPT :    6173.396109 s :
# GPT :    6173.396372 s : 	QAR-FILE-IDX 0 8 41
# GPT :    6173.396673 s : 	xg=(0,16,24,84) ; type=0 ; accuracy=0.lat
# GPT :    6173.396961 s : 	15042003 15042025 15042067 15042068 19760798 41 0 4718728
# GPT :    6173.397285 s :
# GPT :    6173.397545 s : 	QAR-FILE-IDX 0 9 46
# GPT :    6173.397847 s : 	xg=(0,16,6,4) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.398103 s : 	19760798 19760819 19760866 19760867 19982186 46 0 221317
# GPT :    6173.398403 s :
# GPT :    6173.398693 s : 	QAR-FILE-IDX 0 10 39
# GPT :    6173.398997 s : 	xg=(0,16,6,4) ; type=0 ; accuracy=0.lat
# GPT :    6173.399316 s : 	19982186 19982208 19982248 19982249 24700979 39 0 4718728
# GPT :    6173.399622 s :
# GPT :    6173.399949 s : 	QAR-FILE-IDX 0 11 47
# GPT :    6173.400279 s : 	xg=(0,2,24,26) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.400582 s : 	24700979 24701000 24701048 24701049 24922368 47 0 221317
# GPT :    6173.400889 s :
# GPT :    6173.401199 s : 	QAR-FILE-IDX 0 12 40
# GPT :    6173.401535 s : 	xg=(0,2,24,26) ; type=0 ; accuracy=0.lat
# GPT :    6173.401847 s : 	24922368 24922390 24922431 24922432 29641162 40 0 4718728
# GPT :    6173.402194 s :
# GPT :    6173.402513 s : 	QAR-FILE-IDX 0 13 46
# GPT :    6173.402826 s : 	xg=(0,2,3,54) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.403111 s : 	29641162 29641183 29641230 29641231 29862550 46 0 221317
# GPT :    6173.403420 s :
# GPT :    6173.403732 s : 	QAR-FILE-IDX 0 14 39
# GPT :    6173.404003 s : 	xg=(0,2,3,54) ; type=0 ; accuracy=0.lat
# GPT :    6173.404312 s : 	29862550 29862572 29862612 29862613 34581343 39 0 4718728
# GPT :    6173.404618 s :
# GPT :    6173.404908 s : 	QAR-FILE-IDX 0 15 47
# GPT :    6173.405221 s : 	xg=(0,20,4,69) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.405539 s : 	34581343 34581364 34581412 34581413 34802732 47 0 221317
# GPT :    6173.405806 s :
# GPT :    6173.406312 s : 	QAR-FILE-IDX 0 16 40
# GPT :    6173.406621 s : 	xg=(0,20,4,69) ; type=0 ; accuracy=0.lat
# GPT :    6173.406923 s : 	34802732 34802754 34802795 34802796 39521526 40 0 4718728
# GPT :    6173.407260 s :
# GPT :    6173.407552 s : 	QAR-FILE-IDX 0 17 47
# GPT :    6173.407840 s : 	xg=(0,25,0,70) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.408103 s : 	39521526 39521547 39521595 39521596 39742915 47 0 221317
# GPT :    6173.408400 s :
# GPT :    6173.408673 s : 	QAR-FILE-IDX 0 18 40
# GPT :    6173.408920 s : 	xg=(0,25,0,70) ; type=0 ; accuracy=0.lat
# GPT :    6173.409200 s : 	39742915 39742937 39742978 39742979 44461709 40 0 4718728
# GPT :    6173.409491 s :
# GPT :    6173.409740 s : 	QAR-FILE-IDX 0 19 47
# GPT :    6173.410013 s : 	xg=(0,25,7,43) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.410287 s : 	44461709 44461730 44461778 44461779 44683098 47 0 221317
# GPT :    6173.410561 s :
# GPT :    6173.410804 s : 	QAR-FILE-IDX 0 20 40
# GPT :    6173.411072 s : 	xg=(0,25,7,43) ; type=0 ; accuracy=0.lat
# GPT :    6173.411346 s : 	44683098 44683120 44683161 44683162 49401892 40 0 4718728
# GPT :    6173.411606 s :
# GPT :    6173.411862 s : 	QAR-FILE-IDX 0 21 46
# GPT :    6173.412110 s : 	xg=(0,26,2,1) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.412365 s : 	49401892 49401913 49401960 49401961 49623280 46 0 221317
# GPT :    6173.412614 s :
# GPT :    6173.412856 s : 	QAR-FILE-IDX 0 22 39
# GPT :    6173.413121 s : 	xg=(0,26,2,1) ; type=0 ; accuracy=0.lat
# GPT :    6173.414419 s : 	49623280 49623302 49623342 49623343 54342073 39 0 4718728
# GPT :    6173.414742 s :
# GPT :    6173.415002 s : 	QAR-FILE-IDX 0 23 48
# GPT :    6173.415320 s : 	xg=(0,26,36,23) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.415622 s : 	54342073 54342094 54342143 54342144 54563463 48 0 221317
# GPT :    6173.415911 s :
# GPT :    6173.416219 s : 	QAR-FILE-IDX 0 24 41
# GPT :    6173.416518 s : 	xg=(0,26,36,23) ; type=0 ; accuracy=0.lat
# GPT :    6173.416821 s : 	54563463 54563485 54563527 54563528 59282258 41 0 4718728
# GPT :    6173.417077 s :
# GPT :    6173.417397 s : 	QAR-FILE-IDX 0 25 48
# GPT :    6173.417673 s : 	xg=(0,27,24,83) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.417927 s : 	59282258 59282279 59282328 59282329 59503648 48 0 221317
# GPT :    6173.418237 s :
# GPT :    6173.418529 s : 	QAR-FILE-IDX 0 26 41
# GPT :    6173.418820 s : 	xg=(0,27,24,83) ; type=0 ; accuracy=0.lat
# GPT :    6173.419069 s : 	59503648 59503670 59503712 59503713 64222443 41 0 4718728
# GPT :    6173.419381 s :
# GPT :    6173.419625 s : 	QAR-FILE-IDX 0 27 48
# GPT :    6173.419897 s : 	xg=(0,27,24,93) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.420208 s : 	64222443 64222464 64222513 64222514 64443833 48 0 221317
# GPT :    6173.420617 s :
# GPT :    6173.420899 s : 	QAR-FILE-IDX 0 28 41
# GPT :    6173.421179 s : 	xg=(0,27,24,93) ; type=0 ; accuracy=0.lat
# GPT :    6173.421440 s : 	64443833 64443855 64443897 64443898 69162628 41 0 4718728
# GPT :    6173.421698 s :
# GPT :    6173.421962 s : 	QAR-FILE-IDX 0 29 48
# GPT :    6173.422285 s : 	xg=(0,27,37,51) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.422577 s : 	69162628 69162649 69162698 69162699 69384018 48 0 221317
# GPT :    6173.422846 s :
# GPT :    6173.423108 s : 	QAR-FILE-IDX 0 30 41
# GPT :    6173.423373 s : 	xg=(0,27,37,51) ; type=0 ; accuracy=0.lat
# GPT :    6173.423623 s : 	69384018 69384040 69384082 69384083 74102813 41 0 4718728
# GPT :    6173.423894 s :
# GPT :    6173.424144 s : 	QAR-FILE-IDX 0 31 47
# GPT :    6173.424434 s : 	xg=(0,3,17,71) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.424687 s : 	74102813 74102834 74102882 74102883 74324202 47 0 221317
# GPT :    6173.424949 s :
# GPT :    6173.425214 s : 	QAR-FILE-IDX 0 32 40
# GPT :    6173.425474 s : 	xg=(0,3,17,71) ; type=0 ; accuracy=0.lat
# GPT :    6173.425711 s : 	74324202 74324224 74324265 74324266 79042996 40 0 4718728
# GPT :    6173.425991 s :
# GPT :    6173.426240 s : 	QAR-FILE-IDX 0 33 47
# GPT :    6173.426525 s : 	xg=(0,3,41,33) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.427086 s : 	79042996 79043017 79043065 79043066 79264385 47 0 221317
# GPT :    6173.427425 s :
# GPT :    6173.427731 s : 	QAR-FILE-IDX 0 34 40
# GPT :    6173.428048 s : 	xg=(0,3,41,33) ; type=0 ; accuracy=0.lat
# GPT :    6173.428394 s : 	79264385 79264407 79264448 79264449 83983179 40 0 4718728
# GPT :    6173.428687 s :
# GPT :    6173.428979 s : 	QAR-FILE-IDX 0 35 48
# GPT :    6173.429291 s : 	xg=(0,30,38,70) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.429593 s : 	83983179 83983200 83983249 83983250 84204569 48 0 221317
# GPT :    6173.429898 s :
# GPT :    6173.430222 s : 	QAR-FILE-IDX 0 36 41
# GPT :    6173.430516 s : 	xg=(0,30,38,70) ; type=0 ; accuracy=0.lat
# GPT :    6173.430826 s : 	84204569 84204591 84204633 84204634 88923364 41 0 4718728
# GPT :    6173.431114 s :
# GPT :    6173.431426 s : 	QAR-FILE-IDX 0 37 48
# GPT :    6173.431720 s : 	xg=(0,31,13,56) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.432016 s : 	88923364 88923385 88923434 88923435 89144754 48 0 221317
# GPT :    6173.432317 s :
# GPT :    6173.432615 s : 	QAR-FILE-IDX 0 38 41
# GPT :    6173.432914 s : 	xg=(0,31,13,56) ; type=0 ; accuracy=0.lat
# GPT :    6173.433204 s : 	89144754 89144776 89144818 89144819 93863549 41 0 4718728
# GPT :    6173.433488 s :
# GPT :    6173.433783 s : 	QAR-FILE-IDX 0 39 47
# GPT :    6173.434079 s : 	xg=(0,32,38,4) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.434373 s : 	93863549 93863570 93863618 93863619 94084938 47 0 221317
# GPT :    6173.434667 s :
# GPT :    6173.434955 s : 	QAR-FILE-IDX 0 40 40
# GPT :    6173.435254 s : 	xg=(0,32,38,4) ; type=0 ; accuracy=0.lat
# GPT :    6173.435560 s : 	94084938 94084960 94085001 94085002 98803732 40 0 4718728
# GPT :    6173.435858 s :
# GPT :    6173.436133 s : 	QAR-FILE-IDX 0 41 48
# GPT :    6173.436451 s : 	xg=(0,32,44,81) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.436747 s : 	98803732 98803753 98803802 98803803 99025122 48 0 221317
# GPT :    6173.437024 s :
# GPT :    6173.437309 s : 	QAR-FILE-IDX 0 42 41
# GPT :    6173.437600 s : 	xg=(0,32,44,81) ; type=0 ; accuracy=0.lat
# GPT :    6173.437878 s : 	99025122 99025144 99025186 99025187 103743917 41 0 4718728
# GPT :    6173.438143 s :
# GPT :    6173.438423 s : 	QAR-FILE-IDX 0 43 47
# GPT :    6173.438700 s : 	xg=(0,33,3,49) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.439084 s : 	103743917 103743938 103743986 103743987 103965306 47 0 221317
# GPT :    6173.439352 s :
# GPT :    6173.439622 s : 	QAR-FILE-IDX 0 44 40
# GPT :    6173.439872 s : 	xg=(0,33,3,49) ; type=0 ; accuracy=0.lat
# GPT :    6173.440122 s : 	103965306 103965328 103965369 103965370 108684100 40 0 4718728
# GPT :    6173.440397 s :
# GPT :    6173.440665 s : 	QAR-FILE-IDX 0 45 47
# GPT :    6173.440921 s : 	xg=(0,33,39,9) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.441193 s : 	108684100 108684121 108684169 108684170 108905489 47 0 221317
# GPT :    6173.441447 s :
# GPT :    6173.441704 s : 	QAR-FILE-IDX 0 46 40
# GPT :    6173.441967 s : 	xg=(0,33,39,9) ; type=0 ; accuracy=0.lat
# GPT :    6173.442280 s : 	108905489 108905511 108905552 108905553 113624283 40 0 4718728
# GPT :    6173.442720 s :
# GPT :    6173.443064 s : 	QAR-FILE-IDX 0 47 48
# GPT :    6173.443360 s : 	xg=(0,37,22,51) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.443668 s : 	113624283 113624304 113624353 113624354 113845673 48 0 221317
# GPT :    6173.443976 s :
# GPT :    6173.444267 s : 	QAR-FILE-IDX 0 48 41
# GPT :    6173.444514 s : 	xg=(0,37,22,51) ; type=0 ; accuracy=0.lat
# GPT :    6173.444817 s : 	113845673 113845695 113845737 113845738 118564468 41 0 4718728
# GPT :    6173.445081 s :
# GPT :    6173.445363 s : 	QAR-FILE-IDX 0 49 48
# GPT :    6173.445642 s : 	xg=(0,38,17,44) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.445890 s : 	118564468 118564489 118564538 118564539 118785858 48 0 221317
# GPT :    6173.446149 s :
# GPT :    6173.446629 s : 	QAR-FILE-IDX 0 50 41
# GPT :    6173.447258 s : 	xg=(0,38,17,44) ; type=0 ; accuracy=0.lat
# GPT :    6173.447565 s : 	118785858 118785880 118785922 118785923 123504653 41 0 4718728
# GPT :    6173.447817 s :
# GPT :    6173.448051 s : 	QAR-FILE-IDX 0 51 48
# GPT :    6173.448283 s : 	xg=(0,39,20,18) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.448513 s : 	123504653 123504674 123504723 123504724 123726043 48 0 221317
# GPT :    6173.448737 s :
# GPT :    6173.448952 s : 	QAR-FILE-IDX 0 52 41
# GPT :    6173.449170 s : 	xg=(0,39,20,18) ; type=0 ; accuracy=0.lat
# GPT :    6173.449488 s : 	123726043 123726065 123726107 123726108 128444838 41 0 4718728
# GPT :    6173.449776 s :
# GPT :    6173.450048 s : 	QAR-FILE-IDX 0 53 47
# GPT :    6173.450332 s : 	xg=(0,4,42,86) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.450597 s : 	128444838 128444859 128444907 128444908 128666227 47 0 221317
# GPT :    6173.450876 s :
# GPT :    6173.451132 s : 	QAR-FILE-IDX 0 54 40
# GPT :    6173.451391 s : 	xg=(0,4,42,86) ; type=0 ; accuracy=0.lat
# GPT :    6173.460815 s : 	128666227 128666249 128666290 128666291 133385021 40 0 4718728
# GPT :    6173.461056 s :
# GPT :    6173.461321 s : 	QAR-FILE-IDX 0 55 47
# GPT :    6173.461560 s : 	xg=(0,40,1,86) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.461790 s : 	133385021 133385042 133385090 133385091 133606410 47 0 221317
# GPT :    6173.462017 s :
# GPT :    6173.462553 s : 	QAR-FILE-IDX 0 56 40
# GPT :    6173.462753 s : 	xg=(0,40,1,86) ; type=0 ; accuracy=0.lat
# GPT :    6173.462975 s : 	133606410 133606432 133606473 133606474 138325204 40 0 4718728
# GPT :    6173.463233 s :
# GPT :    6173.463475 s : 	QAR-FILE-IDX 0 57 47
# GPT :    6173.463742 s : 	xg=(0,43,19,4) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.463979 s : 	138325204 138325225 138325273 138325274 138546593 47 0 221317
# GPT :    6173.465212 s :
# GPT :    6173.465568 s : 	QAR-FILE-IDX 0 58 40
# GPT :    6173.465994 s : 	xg=(0,43,19,4) ; type=0 ; accuracy=0.lat
# GPT :    6173.466362 s : 	138546593 138546615 138546656 138546657 143265387 40 0 4718728
# GPT :    6173.466625 s :
# GPT :    6173.466841 s : 	QAR-FILE-IDX 0 59 48
# GPT :    6173.467053 s : 	xg=(0,43,22,36) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.467286 s : 	143265387 143265408 143265457 143265458 143486777 48 0 221317
# GPT :    6173.467486 s :
# GPT :    6173.467702 s : 	QAR-FILE-IDX 0 60 41
# GPT :    6173.467920 s : 	xg=(0,43,22,36) ; type=0 ; accuracy=0.lat
# GPT :    6173.468127 s : 	143486777 143486799 143486841 143486842 148205572 41 0 4718728
# GPT :    6173.468359 s :
# GPT :    6173.468552 s : 	QAR-FILE-IDX 0 61 48
# GPT :    6173.468760 s : 	xg=(0,44,23,59) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.468958 s : 	148205572 148205593 148205642 148205643 148426962 48 0 221317
# GPT :    6173.469155 s :
# GPT :    6173.469372 s : 	QAR-FILE-IDX 0 62 41
# GPT :    6173.469564 s : 	xg=(0,44,23,59) ; type=0 ; accuracy=0.lat
# GPT :    6173.469780 s : 	148426962 148426984 148427026 148427027 153145757 41 0 4718728
# GPT :    6173.469994 s :
# GPT :    6173.470210 s : 	QAR-FILE-IDX 0 63 48
# GPT :    6173.470400 s : 	xg=(0,44,39,47) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.470606 s : 	153145757 153145778 153145827 153145828 153367147 48 0 221317
# GPT :    6173.470801 s :
# GPT :    6173.471012 s : 	QAR-FILE-IDX 0 64 41
# GPT :    6173.471228 s : 	xg=(0,44,39,47) ; type=0 ; accuracy=0.lat
# GPT :    6173.471445 s : 	153367147 153367169 153367211 153367212 158085942 41 0 4718728
# GPT :    6173.471646 s :
# GPT :    6173.471846 s : 	QAR-FILE-IDX 0 65 48
# GPT :    6173.472052 s : 	xg=(0,45,44,62) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.472301 s : 	158085942 158085963 158086012 158086013 158307332 48 0 221317
# GPT :    6173.472506 s :
# GPT :    6173.472687 s : 	QAR-FILE-IDX 0 66 41
# GPT :    6173.472894 s : 	xg=(0,45,44,62) ; type=0 ; accuracy=0.lat
# GPT :    6173.473084 s : 	158307332 158307354 158307396 158307397 163026127 41 0 4718728
# GPT :    6173.473311 s :
# GPT :    6173.473492 s : 	QAR-FILE-IDX 0 67 48
# GPT :    6173.475448 s : 	xg=(0,46,38,24) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.475795 s : 	163026127 163026148 163026197 163026198 163247517 48 0 221317
# GPT :    6173.476046 s :
# GPT :    6173.476329 s : 	QAR-FILE-IDX 0 68 41
# GPT :    6173.477660 s : 	xg=(0,46,38,24) ; type=0 ; accuracy=0.lat
# GPT :    6173.477931 s : 	163247517 163247539 163247581 163247582 167966312 41 0 4718728
# GPT :    6173.478194 s :
# GPT :    6173.478476 s : 	QAR-FILE-IDX 0 69 47
# GPT :    6173.478745 s : 	xg=(0,6,17,28) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.479012 s : 	167966312 167966333 167966381 167966382 168187701 47 0 221317
# GPT :    6173.479295 s :
# GPT :    6173.479544 s : 	QAR-FILE-IDX 0 70 40
# GPT :    6173.479819 s : 	xg=(0,6,17,28) ; type=0 ; accuracy=0.lat
# GPT :    6173.480063 s : 	168187701 168187723 168187764 168187765 172906495 40 0 4718728
# GPT :    6173.480351 s :
# GPT :    6173.480705 s : 	QAR-FILE-IDX 0 71 47
# GPT :    6173.481058 s : 	xg=(0,6,36,42) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.481407 s : 	172906495 172906516 172906564 172906565 173127884 47 0 221317
# GPT :    6173.481694 s :
# GPT :    6173.481981 s : 	QAR-FILE-IDX 0 72 40
# GPT :    6173.482334 s : 	xg=(0,6,36,42) ; type=0 ; accuracy=0.lat
# GPT :    6173.482620 s : 	173127884 173127906 173127947 173127948 177846678 40 0 4718728
# GPT :    6173.482892 s :
# GPT :    6173.483151 s : 	QAR-FILE-IDX 0 73 47
# GPT :    6173.483424 s : 	xg=(1,0,27,47) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.483681 s : 	177846678 177846699 177846747 177846748 178068067 47 0 221317
# GPT :    6173.483971 s :
# GPT :    6173.484236 s : 	QAR-FILE-IDX 0 74 40
# GPT :    6173.484480 s : 	xg=(1,0,27,47) ; type=0 ; accuracy=0.lat
# GPT :    6173.484760 s : 	178068067 178068089 178068130 178068131 182786861 40 0 4718728
# GPT :    6173.485028 s :
# GPT :    6173.485297 s : 	QAR-FILE-IDX 0 75 47
# GPT :    6173.485557 s : 	xg=(1,0,31,59) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.485811 s : 	182786861 182786882 182786930 182786931 183008250 47 0 221317
# GPT :    6173.486079 s :
# GPT :    6173.486328 s : 	QAR-FILE-IDX 0 76 40
# GPT :    6173.486618 s : 	xg=(1,0,31,59) ; type=0 ; accuracy=0.lat
# GPT :    6173.486853 s : 	183008250 183008272 183008313 183008314 187727044 40 0 4718728
# GPT :    6173.487132 s :
# GPT :    6173.487407 s : 	QAR-FILE-IDX 0 77 47
# GPT :    6173.487638 s : 	xg=(1,1,36,46) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.487936 s : 	187727044 187727065 187727113 187727114 187948433 47 0 221317
# GPT :    6173.488202 s :
# GPT :    6173.488465 s : 	QAR-FILE-IDX 0 78 40
# GPT :    6173.488740 s : 	xg=(1,1,36,46) ; type=0 ; accuracy=0.lat
# GPT :    6173.488975 s : 	187948433 187948455 187948496 187948497 192667227 40 0 4718728
# GPT :    6173.489246 s :
# GPT :    6173.489495 s : 	QAR-FILE-IDX 0 79 46
# GPT :    6173.489765 s : 	xg=(1,1,36,8) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.490009 s : 	192667227 192667248 192667295 192667296 192888615 46 0 221317
# GPT :    6173.490299 s :
# GPT :    6173.490538 s : 	QAR-FILE-IDX 0 80 39
# GPT :    6173.490804 s : 	xg=(1,1,36,8) ; type=0 ; accuracy=0.lat
# GPT :    6173.491070 s : 	192888615 192888637 192888677 192888678 197607408 39 0 4718728
# GPT :    6173.491329 s :
# GPT :    6173.491573 s : 	QAR-FILE-IDX 0 81 48
# GPT :    6173.491827 s : 	xg=(1,11,47,22) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.492102 s : 	197607408 197607429 197607478 197607479 197828798 48 0 221317
# GPT :    6173.492376 s :
# GPT :    6173.492648 s : 	QAR-FILE-IDX 0 82 41
# GPT :    6173.492883 s : 	xg=(1,11,47,22) ; type=0 ; accuracy=0.lat
# GPT :    6173.493153 s : 	197828798 197828820 197828862 197828863 202547593 41 0 4718728
# GPT :    6173.493403 s :
# GPT :    6173.493677 s : 	QAR-FILE-IDX 0 83 47
# GPT :    6173.493934 s : 	xg=(1,15,3,58) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.494200 s : 	202547593 202547614 202547662 202547663 202768982 47 0 221317
# GPT :    6173.494454 s :
# GPT :    6173.494708 s : 	QAR-FILE-IDX 0 84 40
# GPT :    6173.494981 s : 	xg=(1,15,3,58) ; type=0 ; accuracy=0.lat
# GPT :    6173.495239 s : 	202768982 202769004 202769045 202769046 207487776 40 0 4718728
# GPT :    6173.495504 s :
# GPT :    6173.495751 s : 	QAR-FILE-IDX 0 85 48
# GPT :    6173.495992 s : 	xg=(1,15,34,43) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.496270 s : 	207487776 207487797 207487846 207487847 207709166 48 0 221317
# GPT :    6173.496507 s :
# GPT :    6173.496767 s : 	QAR-FILE-IDX 0 86 41
# GPT :    6173.497049 s : 	xg=(1,15,34,43) ; type=0 ; accuracy=0.lat
# GPT :    6173.497312 s : 	207709166 207709188 207709230 207709231 212427961 41 0 4718728
# GPT :    6173.497576 s :
# GPT :    6173.497838 s : 	QAR-FILE-IDX 0 87 48
# GPT :    6173.498077 s : 	xg=(1,16,14,49) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.498356 s : 	212427961 212427982 212428031 212428032 212649351 48 0 221317
# GPT :    6173.498633 s :
# GPT :    6173.498872 s : 	QAR-FILE-IDX 0 88 41
# GPT :    6173.499138 s : 	xg=(1,16,14,49) ; type=0 ; accuracy=0.lat
# GPT :    6173.499411 s : 	212649351 212649373 212649415 212649416 217368146 41 0 4718728
# GPT :    6173.499661 s :
# GPT :    6173.499909 s : 	QAR-FILE-IDX 0 89 48
# GPT :    6173.500183 s : 	xg=(1,16,27,29) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.500429 s : 	217368146 217368167 217368216 217368217 217589536 48 0 221317
# GPT :    6173.500708 s :
# GPT :    6173.500966 s : 	QAR-FILE-IDX 0 90 41
# GPT :    6173.501242 s : 	xg=(1,16,27,29) ; type=0 ; accuracy=0.lat
# GPT :    6173.501477 s : 	217589536 217589558 217589600 217589601 222308331 41 0 4718728
# GPT :    6173.501749 s :
# GPT :    6173.502012 s : 	QAR-FILE-IDX 0 91 47
# GPT :    6173.502261 s : 	xg=(1,18,1,16) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.502513 s : 	222308331 222308352 222308400 222308401 222529720 47 0 221317
# GPT :    6173.502772 s :
# GPT :    6173.503032 s : 	QAR-FILE-IDX 0 92 40
# GPT :    6173.503284 s : 	xg=(1,18,1,16) ; type=0 ; accuracy=0.lat
# GPT :    6173.503551 s : 	222529720 222529742 222529783 222529784 227248514 40 0 4718728
# GPT :    6173.503801 s :
# GPT :    6173.504049 s : 	QAR-FILE-IDX 0 93 47
# GPT :    6173.504340 s : 	xg=(1,18,9,89) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.504611 s : 	227248514 227248535 227248583 227248584 227469903 47 0 221317
# GPT :    6173.504843 s :
# GPT :    6173.505124 s : 	QAR-FILE-IDX 0 94 40
# GPT :    6173.505397 s : 	xg=(1,18,9,89) ; type=0 ; accuracy=0.lat
# GPT :    6173.505665 s : 	227469903 227469925 227469966 227469967 232188697 40 0 4718728
# GPT :    6173.505925 s :
# GPT :    6173.506184 s : 	QAR-FILE-IDX 0 95 48
# GPT :    6173.506448 s : 	xg=(1,19,23,35) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.506699 s : 	232188697 232188718 232188767 232188768 232410087 48 0 221317
# GPT :    6173.506953 s :
# GPT :    6173.507232 s : 	QAR-FILE-IDX 0 96 41
# GPT :    6173.507503 s : 	xg=(1,19,23,35) ; type=0 ; accuracy=0.lat
# GPT :    6173.507805 s : 	232410087 232410109 232410151 232410152 237128882 41 0 4718728
# GPT :    6173.508082 s :
# GPT :    6173.508353 s : 	QAR-FILE-IDX 0 97 48
# GPT :    6173.508630 s : 	xg=(1,19,31,87) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.508870 s : 	237128882 237128903 237128952 237128953 237350272 48 0 221317
# GPT :    6173.509142 s :
# GPT :    6173.509398 s : 	QAR-FILE-IDX 0 98 41
# GPT :    6173.509639 s : 	xg=(1,19,31,87) ; type=0 ; accuracy=0.lat
# GPT :    6173.509928 s : 	237350272 237350294 237350336 237350337 242069067 41 0 4718728
# GPT :    6173.510198 s :
# GPT :    6173.510448 s : 	QAR-FILE-IDX 0 99 47
# GPT :    6173.510708 s : 	xg=(1,2,18,83) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.510964 s : 	242069067 242069088 242069136 242069137 242290456 47 0 221317
# GPT :    6173.511231 s :
# GPT :    6173.511502 s : 	QAR-FILE-IDX 0 100 40
# GPT :    6173.511752 s : 	xg=(1,2,18,83) ; type=0 ; accuracy=0.lat
# GPT :    6173.512009 s : 	242290456 242290478 242290519 242290520 247009250 40 0 4718728
# GPT :    6173.512300 s :
# GPT :    6173.512558 s : 	QAR-FILE-IDX 0 101 48
# GPT :    6173.512811 s : 	xg=(1,21,26,67) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.513054 s : 	247009250 247009271 247009320 247009321 247230640 48 0 221317
# GPT :    6173.513345 s :
# GPT :    6173.513605 s : 	QAR-FILE-IDX 0 102 41
# GPT :    6173.513870 s : 	xg=(1,21,26,67) ; type=0 ; accuracy=0.lat
# GPT :    6173.514137 s : 	247230640 247230662 247230704 247230705 251949435 41 0 4718728
# GPT :    6173.514392 s :
# GPT :    6173.514676 s : 	QAR-FILE-IDX 0 103 48
# GPT :    6173.514915 s : 	xg=(1,21,37,10) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.515212 s : 	251949435 251949456 251949505 251949506 252170825 48 0 221317
# GPT :    6173.515460 s :
# GPT :    6173.515721 s : 	QAR-FILE-IDX 0 104 41
# GPT :    6173.515980 s : 	xg=(1,21,37,10) ; type=0 ; accuracy=0.lat
# GPT :    6173.516268 s : 	252170825 252170847 252170889 252170890 256889620 41 0 4718728
# GPT :    6173.516517 s :
# GPT :    6173.516772 s : 	QAR-FILE-IDX 0 105 48
# GPT :    6173.517033 s : 	xg=(1,25,34,44) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.517304 s : 	256889620 256889641 256889690 256889691 257111010 48 0 221317
# GPT :    6173.517551 s :
# GPT :    6173.517807 s : 	QAR-FILE-IDX 0 106 41
# GPT :    6173.518087 s : 	xg=(1,25,34,44) ; type=0 ; accuracy=0.lat
# GPT :    6173.518346 s : 	257111010 257111032 257111074 257111075 261829805 41 0 4718728
# GPT :    6173.518613 s :
# GPT :    6173.518853 s : 	QAR-FILE-IDX 0 107 48
# GPT :    6173.519119 s : 	xg=(1,27,16,43) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.519370 s : 	261829805 261829826 261829875 261829876 262051195 48 0 221317
# GPT :    6173.519655 s :
# GPT :    6173.519911 s : 	QAR-FILE-IDX 0 108 41
# GPT :    6173.520185 s : 	xg=(1,27,16,43) ; type=0 ; accuracy=0.lat
# GPT :    6173.520419 s : 	262051195 262051217 262051259 262051260 266769990 41 0 4718728
# GPT :    6173.520691 s :
# GPT :    6173.520936 s : 	QAR-FILE-IDX 0 109 48
# GPT :    6173.521212 s : 	xg=(1,27,38,70) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.521482 s : 	266769990 266770011 266770060 266770061 266991380 48 0 221317
# GPT :    6173.521845 s :
# GPT :    6173.522216 s : 	QAR-FILE-IDX 0 110 41
# GPT :    6173.522571 s : 	xg=(1,27,38,70) ; type=0 ; accuracy=0.lat
# GPT :    6173.522885 s : 	266991380 266991402 266991444 266991445 271710175 41 0 4718728
# GPT :    6173.523242 s :
# GPT :    6173.523587 s : 	QAR-FILE-IDX 0 111 47
# GPT :    6173.523886 s : 	xg=(1,28,45,8) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.524246 s : 	271710175 271710196 271710244 271710245 271931564 47 0 221317
# GPT :    6173.524593 s :
# GPT :    6173.524905 s : 	QAR-FILE-IDX 0 112 40
# GPT :    6173.525269 s : 	xg=(1,28,45,8) ; type=0 ; accuracy=0.lat
# GPT :    6173.525625 s : 	271931564 271931586 271931627 271931628 276650358 40 0 4718728
# GPT :    6173.525944 s :
# GPT :    6173.526296 s : 	QAR-FILE-IDX 0 113 47
# GPT :    6173.526622 s : 	xg=(1,29,6,35) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.526974 s : 	276650358 276650379 276650427 276650428 276871747 47 0 221317
# GPT :    6173.527343 s :
# GPT :    6173.527675 s : 	QAR-FILE-IDX 0 114 40
# GPT :    6173.528005 s : 	xg=(1,29,6,35) ; type=0 ; accuracy=0.lat
# GPT :    6173.528388 s : 	276871747 276871769 276871810 276871811 281590541 40 0 4718728
# GPT :    6173.528724 s :
# GPT :    6173.529034 s : 	QAR-FILE-IDX 0 115 46
# GPT :    6173.529408 s : 	xg=(1,31,3,0) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.529765 s : 	281590541 281590562 281590609 281590610 281811929 46 0 221317
# GPT :    6173.530114 s :
# GPT :    6173.530386 s : 	QAR-FILE-IDX 0 116 39
# GPT :    6173.530693 s : 	xg=(1,31,3,0) ; type=0 ; accuracy=0.lat
# GPT :    6173.530980 s : 	281811929 281811951 281811991 281811992 286530722 39 0 4718728
# GPT :    6173.531300 s :
# GPT :    6173.540853 s : 	QAR-FILE-IDX 0 117 48
# GPT :    6173.541193 s : 	xg=(1,33,36,88) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.541688 s : 	286530722 286530743 286530792 286530793 286752112 48 0 221317
# GPT :    6173.542064 s :
# GPT :    6173.542475 s : 	QAR-FILE-IDX 0 118 41
# GPT :    6173.542822 s : 	xg=(1,33,36,88) ; type=0 ; accuracy=0.lat
# GPT :    6173.543231 s : 	286752112 286752134 286752176 286752177 291470907 41 0 4718728
# GPT :    6173.543591 s :
# GPT :    6173.543947 s : 	QAR-FILE-IDX 0 119 48
# GPT :    6173.544321 s : 	xg=(1,33,47,64) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.544686 s : 	291470907 291470928 291470977 291470978 291692297 48 0 221317
# GPT :    6173.545040 s :
# GPT :    6173.545483 s : 	QAR-FILE-IDX 0 120 41
# GPT :    6173.545890 s : 	xg=(1,33,47,64) ; type=0 ; accuracy=0.lat
# GPT :    6173.546361 s : 	291692297 291692319 291692361 291692362 296411092 41 0 4718728
# GPT :    6173.546762 s :
# GPT :    6173.547264 s : 	QAR-FILE-IDX 0 121 48
# GPT :    6173.547686 s : 	xg=(1,34,45,88) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.547975 s : 	296411092 296411113 296411162 296411163 296632482 48 0 221317
# GPT :    6173.548295 s :
# GPT :    6173.548565 s : 	QAR-FILE-IDX 0 122 41
# GPT :    6173.548857 s : 	xg=(1,34,45,88) ; type=0 ; accuracy=0.lat
# GPT :    6173.550348 s : 	296632482 296632504 296632546 296632547 301351277 41 0 4718728
# GPT :    6173.550609 s :
# GPT :    6173.550892 s : 	QAR-FILE-IDX 0 123 48
# GPT :    6173.551152 s : 	xg=(1,41,41,24) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.551512 s : 	301351277 301351298 301351347 301351348 301572667 48 0 221317
# GPT :    6173.551942 s :
# GPT :    6173.552286 s : 	QAR-FILE-IDX 0 124 41
# GPT :    6173.552614 s : 	xg=(1,41,41,24) ; type=0 ; accuracy=0.lat
# GPT :    6173.552939 s : 	301572667 301572689 301572731 301572732 306291462 41 0 4718728
# GPT :    6173.553255 s :
# GPT :    6173.553576 s : 	QAR-FILE-IDX 0 125 48
# GPT :    6173.553906 s : 	xg=(1,42,10,47) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.554216 s : 	306291462 306291483 306291532 306291533 306512852 48 0 221317
# GPT :    6173.554575 s :
# GPT :    6173.554900 s : 	QAR-FILE-IDX 0 126 41
# GPT :    6173.555184 s : 	xg=(1,42,10,47) ; type=0 ; accuracy=0.lat
# GPT :    6173.555536 s : 	306512852 306512874 306512916 306512917 311231647 41 0 4718728
# GPT :    6173.555867 s :
# GPT :    6173.556168 s : 	QAR-FILE-IDX 0 127 48
# GPT :    6173.556511 s : 	xg=(1,42,12,73) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.556859 s : 	311231647 311231668 311231717 311231718 311453037 48 0 221317
# GPT :    6173.557187 s :
# GPT :    6173.557544 s : 	QAR-FILE-IDX 0 128 41
# GPT :    6173.557887 s : 	xg=(1,42,12,73) ; type=0 ; accuracy=0.lat
# GPT :    6173.558198 s : 	311453037 311453059 311453101 311453102 316171832 41 0 4718728
# GPT :    6173.558559 s :
# GPT :    6173.558896 s : 	QAR-FILE-IDX 0 129 48
# GPT :    6173.559190 s : 	xg=(1,45,25,59) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.559554 s : 	316171832 316171853 316171902 316171903 316393222 48 0 221317
# GPT :    6173.560046 s :
# GPT :    6173.560352 s : 	QAR-FILE-IDX 0 130 41
# GPT :    6173.560768 s : 	xg=(1,45,25,59) ; type=0 ; accuracy=0.lat
# GPT :    6173.561221 s : 	316393222 316393244 316393286 316393287 321112017 41 0 4718728
# GPT :    6173.561602 s :
# GPT :    6173.561987 s : 	QAR-FILE-IDX 0 131 48
# GPT :    6173.562357 s : 	xg=(1,47,16,91) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.562721 s : 	321112017 321112038 321112087 321112088 321333407 48 0 221317
# GPT :    6173.563036 s :
# GPT :    6173.563376 s : 	QAR-FILE-IDX 0 132 41
# GPT :    6173.563675 s : 	xg=(1,47,16,91) ; type=0 ; accuracy=0.lat
# GPT :    6173.563991 s : 	321333407 321333429 321333471 321333472 326052202 41 0 4718728
# GPT :    6173.564334 s :
# GPT :    6173.564640 s : 	QAR-FILE-IDX 0 133 48
# GPT :    6173.564955 s : 	xg=(1,47,28,72) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.565340 s : 	326052202 326052223 326052272 326052273 326273592 48 0 221317
# GPT :    6173.565686 s :
# GPT :    6173.566007 s : 	QAR-FILE-IDX 0 134 41
# GPT :    6173.566330 s : 	xg=(1,47,28,72) ; type=0 ; accuracy=0.lat
# GPT :    6173.566605 s : 	326273592 326273614 326273656 326273657 330992387 41 0 4718728
# GPT :    6173.566827 s :
# GPT :    6173.567065 s : 	QAR-FILE-IDX 0 135 48
# GPT :    6173.567337 s : 	xg=(1,47,40,67) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.567573 s : 	330992387 330992408 330992457 330992458 331213777 48 0 221317
# GPT :    6173.568304 s :
# GPT :    6173.568679 s : 	QAR-FILE-IDX 0 136 41
# GPT :    6173.569004 s : 	xg=(1,47,40,67) ; type=0 ; accuracy=0.lat
# GPT :    6173.569322 s : 	331213777 331213799 331213841 331213842 335932572 41 0 4718728
# GPT :    6173.569615 s :
# GPT :    6173.572700 s : 	QAR-FILE-IDX 0 137 48
# GPT :    6173.573006 s : 	xg=(1,47,43,76) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.573309 s : 	335932572 335932593 335932642 335932643 336153962 48 0 221317
# GPT :    6173.573574 s :
# GPT :    6173.573864 s : 	QAR-FILE-IDX 0 138 41
# GPT :    6173.574129 s : 	xg=(1,47,43,76) ; type=0 ; accuracy=0.lat
# GPT :    6173.574421 s : 	336153962 336153984 336154026 336154027 340872757 41 0 4718728
# GPT :    6173.574688 s :
# GPT :    6173.574949 s : 	QAR-FILE-IDX 0 139 47
# GPT :    6173.575229 s : 	xg=(1,5,35,35) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.575469 s : 	340872757 340872778 340872826 340872827 341094146 47 0 221317
# GPT :    6173.575743 s :
# GPT :    6173.576011 s : 	QAR-FILE-IDX 0 140 40
# GPT :    6173.576276 s : 	xg=(1,5,35,35) ; type=0 ; accuracy=0.lat
# GPT :    6173.576520 s : 	341094146 341094168 341094209 341094210 345812940 40 0 4718728
# GPT :    6173.576777 s :
# GPT :    6173.577039 s : 	QAR-FILE-IDX 0 141 47
# GPT :    6173.577291 s : 	xg=(1,7,21,52) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.577561 s : 	345812940 345812961 345813009 345813010 346034329 47 0 221317
# GPT :    6173.577802 s :
# GPT :    6173.578056 s : 	QAR-FILE-IDX 0 142 40
# GPT :    6173.578336 s : 	xg=(1,7,21,52) ; type=0 ; accuracy=0.lat
# GPT :    6173.578584 s : 	346034329 346034351 346034392 346034393 350753123 40 0 4718728
# GPT :    6173.578830 s :
# GPT :    6173.579084 s : 	QAR-FILE-IDX 0 143 47
# GPT :    6173.579345 s : 	xg=(1,8,33,55) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.579618 s : 	350753123 350753144 350753192 350753193 350974512 47 0 221317
# GPT :    6173.579857 s :
# GPT :    6173.580100 s : 	QAR-FILE-IDX 0 144 40
# GPT :    6173.580358 s : 	xg=(1,8,33,55) ; type=0 ; accuracy=0.lat
# GPT :    6173.580604 s : 	350974512 350974534 350974575 350974576 355693306 40 0 4718728
# GPT :    6173.580854 s :
# GPT :    6173.581117 s : 	QAR-FILE-IDX 0 145 48
# GPT :    6173.581423 s : 	xg=(10,0,16,38) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.581665 s : 	355693306 355693327 355693376 355693377 355914696 48 0 221317
# GPT :    6173.581934 s :
# GPT :    6173.582183 s : 	QAR-FILE-IDX 0 146 41
# GPT :    6173.582463 s : 	xg=(10,0,16,38) ; type=0 ; accuracy=0.lat
# GPT :    6173.582722 s : 	355914696 355914718 355914760 355914761 360633491 41 0 4718728
# GPT :    6173.582971 s :
# GPT :    6173.583261 s : 	QAR-FILE-IDX 0 147 47
# GPT :    6173.583512 s : 	xg=(10,1,5,26) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.583763 s : 	360633491 360633512 360633560 360633561 360854880 47 0 221317
# GPT :    6173.584044 s :
# GPT :    6173.584323 s : 	QAR-FILE-IDX 0 148 40
# GPT :    6173.584610 s : 	xg=(10,1,5,26) ; type=0 ; accuracy=0.lat
# GPT :    6173.584949 s : 	360854880 360854902 360854943 360854944 365573674 40 0 4718728
# GPT :    6173.585242 s :
# GPT :    6173.585484 s : 	QAR-FILE-IDX 0 149 49
# GPT :    6173.585765 s : 	xg=(10,11,20,26) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.586014 s : 	365573674 365573695 365573745 365573746 365795065 49 0 221317
# GPT :    6173.586331 s :
# GPT :    6173.586612 s : 	QAR-FILE-IDX 0 150 42
# GPT :    6173.586863 s : 	xg=(10,11,20,26) ; type=0 ; accuracy=0.lat
# GPT :    6173.587089 s : 	365795065 365795087 365795130 365795131 370513861 42 0 4718728
# GPT :    6173.587382 s :
# GPT :    6173.587652 s : 	QAR-FILE-IDX 0 151 49
# GPT :    6173.587898 s : 	xg=(10,11,22,90) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.588134 s : 	370513861 370513882 370513932 370513933 370735252 49 0 221317
# GPT :    6173.588419 s :
# GPT :    6173.588736 s : 	QAR-FILE-IDX 0 152 42
# GPT :    6173.589272 s : 	xg=(10,11,22,90) ; type=0 ; accuracy=0.lat
# GPT :    6173.589658 s : 	370735252 370735274 370735317 370735318 375454048 42 0 4718728
# GPT :    6173.589921 s :
# GPT :    6173.590188 s : 	QAR-FILE-IDX 0 153 49
# GPT :    6173.590481 s : 	xg=(10,11,42,18) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.590748 s : 	375454048 375454069 375454119 375454120 375675439 49 0 221317
# GPT :    6173.590995 s :
# GPT :    6173.591319 s : 	QAR-FILE-IDX 0 154 42
# GPT :    6173.591610 s : 	xg=(10,11,42,18) ; type=0 ; accuracy=0.lat
# GPT :    6173.591933 s : 	375675439 375675461 375675504 375675505 380394235 42 0 4718728
# GPT :    6173.592227 s :
# GPT :    6173.592528 s : 	QAR-FILE-IDX 0 155 49
# GPT :    6173.592850 s : 	xg=(10,14,31,37) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.593086 s : 	380394235 380394256 380394306 380394307 380615626 49 0 221317
# GPT :    6173.593396 s :
# GPT :    6173.593696 s : 	QAR-FILE-IDX 0 156 42
# GPT :    6173.598989 s : 	xg=(10,14,31,37) ; type=0 ; accuracy=0.lat
# GPT :    6173.599277 s : 	380615626 380615648 380615691 380615692 385334422 42 0 4718728
# GPT :    6173.599501 s :
# GPT :    6173.599730 s : 	QAR-FILE-IDX 0 157 48
# GPT :    6173.599953 s : 	xg=(10,16,2,89) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.600160 s : 	385334422 385334443 385334492 385334493 385555812 48 0 221317
# GPT :    6173.600349 s :
# GPT :    6173.600560 s : 	QAR-FILE-IDX 0 158 41
# GPT :    6173.600767 s : 	xg=(10,16,2,89) ; type=0 ; accuracy=0.lat
# GPT :    6173.600962 s : 	385555812 385555834 385555876 385555877 390274607 41 0 4718728
# GPT :    6173.601159 s :
# GPT :    6173.601360 s : 	QAR-FILE-IDX 0 159 49
# GPT :    6173.601580 s : 	xg=(10,18,23,51) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.602534 s : 	390274607 390274628 390274678 390274679 390495998 49 0 221317
# GPT :    6173.602752 s :
# GPT :    6173.603094 s : 	QAR-FILE-IDX 0 160 42
# GPT :    6173.603345 s : 	xg=(10,18,23,51) ; type=0 ; accuracy=0.lat
# GPT :    6173.603644 s : 	390495998 390496020 390496063 390496064 395214794 42 0 4718728
# GPT :    6173.603930 s :
# GPT :    6173.604179 s : 	QAR-FILE-IDX 0 161 47
# GPT :    6173.604468 s : 	xg=(10,18,9,4) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.604729 s : 	395214794 395214815 395214863 395214864 395436183 47 0 221317
# GPT :    6173.605001 s :
# GPT :    6173.605235 s : 	QAR-FILE-IDX 0 162 40
# GPT :    6173.605454 s : 	xg=(10,18,9,4) ; type=0 ; accuracy=0.lat
# GPT :    6173.605643 s : 	395436183 395436205 395436246 395436247 400154977 40 0 4718728
# GPT :    6173.605854 s :
# GPT :    6173.606055 s : 	QAR-FILE-IDX 0 163 49
# GPT :    6173.606306 s : 	xg=(10,20,23,59) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.606492 s : 	400154977 400154998 400155048 400155049 400376368 49 0 221317
# GPT :    6173.606697 s :
# GPT :    6173.606903 s : 	QAR-FILE-IDX 0 164 42
# GPT :    6173.607088 s : 	xg=(10,20,23,59) ; type=0 ; accuracy=0.lat
# GPT :    6173.607330 s : 	400376368 400376390 400376433 400376434 405095164 42 0 4718728
# GPT :    6173.607543 s :
# GPT :    6173.607756 s : 	QAR-FILE-IDX 0 165 48
# GPT :    6173.607942 s : 	xg=(10,21,29,0) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.608151 s : 	405095164 405095185 405095234 405095235 405316554 48 0 221317
# GPT :    6173.608375 s :
# GPT :    6173.608557 s : 	QAR-FILE-IDX 0 166 41
# GPT :    6173.608762 s : 	xg=(10,21,29,0) ; type=0 ; accuracy=0.lat
# GPT :    6173.608984 s : 	405316554 405316576 405316618 405316619 410035349 41 0 4718728
# GPT :    6173.609169 s :
# GPT :    6173.609358 s : 	QAR-FILE-IDX 0 167 48
# GPT :    6173.609577 s : 	xg=(10,22,0,62) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.609797 s : 	410035349 410035370 410035419 410035420 410256739 48 0 221317
# GPT :    6173.610011 s :
# GPT :    6173.610220 s : 	QAR-FILE-IDX 0 168 41
# GPT :    6173.610397 s : 	xg=(10,22,0,62) ; type=0 ; accuracy=0.lat
# GPT :    6173.610620 s : 	410256739 410256761 410256803 410256804 414975534 41 0 4718728
# GPT :    6173.610835 s :
# GPT :    6173.611034 s : 	QAR-FILE-IDX 0 169 49
# GPT :    6173.611248 s : 	xg=(10,22,10,88) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.611459 s : 	414975534 414975555 414975605 414975606 415196925 49 0 221317
# GPT :    6173.611674 s :
# GPT :    6173.611895 s : 	QAR-FILE-IDX 0 170 42
# GPT :    6173.612097 s : 	xg=(10,22,10,88) ; type=0 ; accuracy=0.lat
# GPT :    6173.612308 s : 	415196925 415196947 415196990 415196991 419915721 42 0 4718728
# GPT :    6173.612500 s :
# GPT :    6173.612716 s : 	QAR-FILE-IDX 0 171 48
# GPT :    6173.612928 s : 	xg=(10,23,6,86) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.613137 s : 	419915721 419915742 419915791 419915792 420137111 48 0 221317
# GPT :    6173.613383 s :
# GPT :    6173.613606 s : 	QAR-FILE-IDX 0 172 41
# GPT :    6173.613819 s : 	xg=(10,23,6,86) ; type=0 ; accuracy=0.lat
# GPT :    6173.614022 s : 	420137111 420137133 420137175 420137176 424855906 41 0 4718728
# GPT :    6173.614279 s :
# GPT :    6173.614495 s : 	QAR-FILE-IDX 0 173 49
# GPT :    6173.614701 s : 	xg=(10,24,15,53) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.614902 s : 	424855906 424855927 424855977 424855978 425077297 49 0 221317
# GPT :    6173.615087 s :
# GPT :    6173.615325 s : 	QAR-FILE-IDX 0 174 42
# GPT :    6173.615530 s : 	xg=(10,24,15,53) ; type=0 ; accuracy=0.lat
# GPT :    6173.615708 s : 	425077297 425077319 425077362 425077363 429796093 42 0 4718728
# GPT :    6173.615922 s :
# GPT :    6173.616126 s : 	QAR-FILE-IDX 0 175 49
# GPT :    6173.616327 s : 	xg=(10,24,19,86) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.616537 s : 	429796093 429796114 429796164 429796165 430017484 49 0 221317
# GPT :    6173.616750 s :
# GPT :    6173.616933 s : 	QAR-FILE-IDX 0 176 42
# GPT :    6173.617143 s : 	xg=(10,24,19,86) ; type=0 ; accuracy=0.lat
# GPT :    6173.617382 s : 	430017484 430017506 430017549 430017550 434736280 42 0 4718728
# GPT :    6173.617596 s :
# GPT :    6173.617792 s : 	QAR-FILE-IDX 0 177 49
# GPT :    6173.617999 s : 	xg=(10,24,24,21) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.618226 s : 	434736280 434736301 434736351 434736352 434957671 49 0 221317
# GPT :    6173.618438 s :
# GPT :    6173.618607 s : 	QAR-FILE-IDX 0 178 42
# GPT :    6173.618819 s : 	xg=(10,24,24,21) ; type=0 ; accuracy=0.lat
# GPT :    6173.619043 s : 	434957671 434957693 434957736 434957737 439676467 42 0 4718728
# GPT :    6173.619255 s :
# GPT :    6173.619464 s : 	QAR-FILE-IDX 0 179 48
# GPT :    6173.619684 s : 	xg=(10,24,3,32) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.619885 s : 	439676467 439676488 439676537 439676538 439897857 48 0 221317
# GPT :    6173.620086 s :
# GPT :    6173.620286 s : 	QAR-FILE-IDX 0 180 41
# GPT :    6173.620507 s : 	xg=(10,24,3,32) ; type=0 ; accuracy=0.lat
# GPT :    6173.620711 s : 	439897857 439897879 439897921 439897922 444616652 41 0 4718728
# GPT :    6173.620931 s :
# GPT :    6173.621140 s : 	QAR-FILE-IDX 0 181 49
# GPT :    6173.621333 s : 	xg=(10,24,37,12) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.621512 s : 	444616652 444616673 444616723 444616724 444838043 49 0 221317
# GPT :    6173.621735 s :
# GPT :    6173.621956 s : 	QAR-FILE-IDX 0 182 42
# GPT :    6173.622152 s : 	xg=(10,24,37,12) ; type=0 ; accuracy=0.lat
# GPT :    6173.622353 s : 	444838043 444838065 444838108 444838109 449556839 42 0 4718728
# GPT :    6173.622561 s :
# GPT :    6173.622774 s : 	QAR-FILE-IDX 0 183 48
# GPT :    6173.622976 s : 	xg=(10,24,4,19) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.623236 s : 	449556839 449556860 449556909 449556910 449778229 48 0 221317
# GPT :    6173.623499 s :
# GPT :    6173.623747 s : 	QAR-FILE-IDX 0 184 41
# GPT :    6173.623976 s : 	xg=(10,24,4,19) ; type=0 ; accuracy=0.lat
# GPT :    6173.624235 s : 	449778229 449778251 449778293 449778294 454497024 41 0 4718728
# GPT :    6173.624467 s :
# GPT :    6173.624712 s : 	QAR-FILE-IDX 0 185 49
# GPT :    6173.624926 s : 	xg=(10,25,30,29) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.625214 s : 	454497024 454497045 454497095 454497096 454718415 49 0 221317
# GPT :    6173.625432 s :
# GPT :    6173.625654 s : 	QAR-FILE-IDX 0 186 42
# GPT :    6173.625861 s : 	xg=(10,25,30,29) ; type=0 ; accuracy=0.lat
# GPT :    6173.626110 s : 	454718415 454718437 454718480 454718481 459437211 42 0 4718728
# GPT :    6173.626338 s :
# GPT :    6173.626601 s : 	QAR-FILE-IDX 0 187 49
# GPT :    6173.626838 s : 	xg=(10,26,13,23) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.627022 s : 	459437211 459437232 459437282 459437283 459658602 49 0 221317
# GPT :    6173.627244 s :
# GPT :    6173.627482 s : 	QAR-FILE-IDX 0 188 42
# GPT :    6173.627709 s : 	xg=(10,26,13,23) ; type=0 ; accuracy=0.lat
# GPT :    6173.627932 s : 	459658602 459658624 459658667 459658668 464377398 42 0 4718728
# GPT :    6173.628134 s :
# GPT :    6173.628364 s : 	QAR-FILE-IDX 0 189 48
# GPT :    6173.628594 s : 	xg=(10,26,4,95) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.628803 s : 	464377398 464377419 464377468 464377469 464598788 48 0 221317
# GPT :    6173.629042 s :
# GPT :    6173.629274 s : 	QAR-FILE-IDX 0 190 41
# GPT :    6173.629502 s : 	xg=(10,26,4,95) ; type=0 ; accuracy=0.lat
# GPT :    6173.629730 s : 	464598788 464598810 464598852 464598853 469317583 41 0 4718728
# GPT :    6173.630031 s :
# GPT :    6173.636633 s : 	QAR-FILE-IDX 0 191 48
# GPT :    6173.636924 s : 	xg=(10,27,6,67) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.637143 s : 	469317583 469317604 469317653 469317654 469538973 48 0 221317
# GPT :    6173.637382 s :
# GPT :    6173.637618 s : 	QAR-FILE-IDX 0 192 41
# GPT :    6173.637907 s : 	xg=(10,27,6,67) ; type=0 ; accuracy=0.lat
# GPT :    6173.638144 s : 	469538973 469538995 469539037 469539038 474257768 41 0 4718728
# GPT :    6173.638374 s :
# GPT :    6173.638598 s : 	QAR-FILE-IDX 0 193 49
# GPT :    6173.638816 s : 	xg=(10,28,12,11) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.639045 s : 	474257768 474257789 474257839 474257840 474479159 49 0 221317
# GPT :    6173.639325 s :
# GPT :    6173.639563 s : 	QAR-FILE-IDX 0 194 42
# GPT :    6173.639770 s : 	xg=(10,28,12,11) ; type=0 ; accuracy=0.lat
# GPT :    6173.639998 s : 	474479159 474479181 474479224 474479225 479197955 42 0 4718728
# GPT :    6173.640266 s :
# GPT :    6173.640520 s : 	QAR-FILE-IDX 0 195 49
# GPT :    6173.640764 s : 	xg=(10,28,38,32) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.641013 s : 	479197955 479197976 479198026 479198027 479419346 49 0 221317
# GPT :    6173.641281 s :
# GPT :    6173.641537 s : 	QAR-FILE-IDX 0 196 42
# GPT :    6173.641765 s : 	xg=(10,28,38,32) ; type=0 ; accuracy=0.lat
# GPT :    6173.642010 s : 	479419346 479419368 479419411 479419412 484138142 42 0 4718728
# GPT :    6173.642299 s :
# GPT :    6173.642558 s : 	QAR-FILE-IDX 0 197 49
# GPT :    6173.642776 s : 	xg=(10,30,13,16) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.643039 s : 	484138142 484138163 484138213 484138214 484359533 49 0 221317
# GPT :    6173.643322 s :
# GPT :    6173.645636 s : 	QAR-FILE-IDX 0 198 42
# GPT :    6173.646035 s : 	xg=(10,30,13,16) ; type=0 ; accuracy=0.lat
# GPT :    6173.646383 s : 	484359533 484359555 484359598 484359599 489078329 42 0 4718728
# GPT :    6173.646668 s :
# GPT :    6173.646979 s : 	QAR-FILE-IDX 0 199 49
# GPT :    6173.647260 s : 	xg=(10,31,40,66) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.647539 s : 	489078329 489078350 489078400 489078401 489299720 49 0 221317
# GPT :    6173.647805 s :
# GPT :    6173.648064 s : 	QAR-FILE-IDX 0 200 42
# GPT :    6173.648316 s : 	xg=(10,31,40,66) ; type=0 ; accuracy=0.lat
# GPT :    6173.648571 s : 	489299720 489299742 489299785 489299786 494018516 42 0 4718728
# GPT :    6173.648841 s :
# GPT :    6173.649092 s : 	QAR-FILE-IDX 0 201 49
# GPT :    6173.649361 s : 	xg=(10,34,41,58) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.650290 s : 	494018516 494018537 494018587 494018588 494239907 49 0 221317
# GPT :    6173.650603 s :
# GPT :    6173.650841 s : 	QAR-FILE-IDX 0 202 42
# GPT :    6173.651100 s : 	xg=(10,34,41,58) ; type=0 ; accuracy=0.lat
# GPT :    6173.651382 s : 	494239907 494239929 494239972 494239973 498958703 42 0 4718728
# GPT :    6173.651641 s :
# GPT :    6173.651910 s : 	QAR-FILE-IDX 0 203 49
# GPT :    6173.652183 s : 	xg=(10,34,43,74) ; type=0 ; accuracy=0 ; wsnk.lat
# GPT :    6173.652504 s : 	498958703 498958724 498958774 498958775 499180094 49 0 221317
# GPT :    6173.652806 s :
# GPT :    6173.653095 s : 	QAR-FILE-IDX 0 204 42
# GPT :    6173.653398 s : 	xg=(10,34,43,74) ; type=0 ; accuracy=0.lat
# GPT :    6173.653697 s : 	499180094 499180116 499180159 499180160 503898890 42 0 4718728
# GPT :    6173.653968 s :
# GPT :    6173.654260 s : 	QAR-FILE-IDX 0 205 49
# ...
# GPT :    6213.076536 s :
# GPT :    6213.078435 s :
# GPT :    6213.080230 s :
# GPT :    6213.082030 s :
# GPT :    6213.083729 s :
# GPT :    6213.085530 s :
# GPT :    6213.087305 s :
# GPT :    6213.089046 s :
# GPT :    6213.090793 s :
# GPT :    6213.093170 s :
# GPT :    6213.094449 s :
# GPT :    6213.099455 s :
# GPT :    6213.101259 s :
# GPT :    6213.103054 s :
# GPT :    6213.104839 s :
# GPT :    6213.106705 s :
# GPT :    6213.108515 s :
# GPT :    6213.110299 s :
# GPT :    6213.112003 s :
# GPT :    6213.115148 s :
# GPT :    6213.117589 s :
# GPT :    6213.120490 s :
# GPT :    6213.122827 s :
# GPT :    6213.124783 s :
# GPT :    6213.126614 s :
# GPT :    6213.128931 s :
# GPT :    6213.130126 s :
# GPT :    6213.131874 s :
# GPT :    6213.133595 s :
# GPT :    6213.135343 s :
# GPT :    6213.137051 s :
# GPT :    6213.138772 s :
# GPT :    6213.140466 s :
# GPT :    6213.142210 s :
# GPT :    6213.143957 s :
# GPT :    6213.145669 s :
# GPT :    6213.147407 s :
# GPT :    6213.149098 s :
# GPT :    6213.150826 s :
# GPT :    6213.152559 s :
# GPT :    6213.154302 s :
# GPT :    6213.156656 s :
# GPT :    6213.157833 s :
# GPT :    6213.159547 s :
# GPT :    6213.161267 s :
# GPT :    6213.162975 s :
# GPT :    6213.164730 s :
# GPT :    6213.166679 s :
# GPT :    6213.170294 s :
# GPT :    6213.172651 s :
# GPT :    6213.174735 s :
# GPT :    6213.177081 s :
# GPT :    6213.179306 s :
# GPT :    6213.181396 s :
# GPT :    6213.183241 s :
# GPT :    6213.185715 s :
# GPT :    6213.188478 s :
# GPT :    6213.191035 s :
# GPT :    6213.192251 s :
# GPT :    6213.194020 s :
# GPT :    6213.196576 s :
# GPT :    6213.198755 s :
# GPT :    6213.200544 s :
# GPT :    6213.202227 s :
# GPT :    6213.203906 s :
# GPT :    6213.205624 s :
# GPT :    6213.207411 s :
# GPT :    6213.209100 s :
# GPT :    6213.210791 s :
# GPT :    6213.212599 s :
# GPT :    6213.214299 s :
# GPT :    6213.215977 s :
# GPT :    6213.220532 s :
# GPT :    6213.222871 s :
# GPT :    6213.224258 s :
# GPT :    6213.226051 s :
# GPT :    6213.227937 s :
# GPT :    6213.229773 s :
# GPT :    6213.231612 s :
# GPT :    6213.233298 s :
# GPT :    6213.235002 s :
# GPT :    6213.236680 s :
# GPT :    6213.238374 s :
# GPT :    6213.240060 s :
# GPT :    6213.241752 s :
# GPT :    6213.243396 s :
# GPT :    6213.245224 s :
# GPT :    6213.247051 s :
# GPT :    6213.248837 s :
# GPT :    6213.251065 s :
# GPT :    6213.252244 s :
# GPT :    6213.253956 s :
# GPT :    6213.255648 s :
# GPT :    6213.257407 s :
# GPT :    6213.259817 s :
# GPT :    6213.261659 s :
# GPT :    6213.263352 s :
# GPT :    6213.265080 s :
# GPT :    6213.269132 s :
# GPT :    6213.271201 s :
# GPT :    6213.273221 s :
# GPT :    6213.275296 s :
# GPT :    6213.277383 s :
# GPT :    6213.279436 s :
# GPT :    6213.281533 s :
# GPT :    6213.283956 s :
# GPT :    6213.285151 s :
# GPT :    6213.286982 s :
# GPT :    6213.288702 s :
# GPT :    6213.290433 s :
# GPT :    6213.292156 s :
# GPT :    6213.293883 s :
# GPT :    6213.295579 s :
# GPT :    6213.297278 s :
# GPT :    6213.298951 s :
# GPT :    6213.300630 s :
# GPT :    6213.302315 s :
# GPT :    6213.304000 s :
# GPT :    6213.305679 s :
# GPT :    6213.307366 s :
# GPT :    6213.309079 s :
# GPT :    6213.311332 s :
# GPT :    6213.312474 s :
# GPT :    6213.314148 s :
# GPT :    6213.315817 s :
# GPT :    6213.317513 s :
# GPT :    6213.319281 s :
# GPT :    6213.320979 s :
# GPT :    6213.322820 s :
# GPT :    6213.324485 s :
# GPT :    6213.326326 s :
# GPT :    6213.328017 s :
# GPT :    6213.329837 s :
# GPT :    6213.331545 s :
# GPT :    6213.333391 s :
# GPT :    6213.335109 s :
# GPT :    6213.336823 s :
# GPT :    6213.339055 s :
# GPT :    6213.340240 s :
# GPT :    6213.341922 s :
# GPT :    6213.343623 s :
# GPT :    6213.345303 s :
# GPT :    6213.346991 s :
# GPT :    6213.348677 s :
# GPT :    6213.350352 s :
# GPT :    6213.352036 s :
# GPT :    6213.353730 s :
# GPT :    6213.355450 s :
# GPT :    6213.357279 s :
# GPT :    6213.359017 s :
# GPT :    6213.361498 s :
# GPT :    6213.363769 s :
# GPT :    6213.365508 s :
# GPT :    6213.367262 s :
# GPT :    6213.368935 s :
# GPT :    6213.370646 s :
# GPT :    6213.372358 s :
# GPT :    6213.374980 s :
# GPT :    6213.377566 s :
# GPT :    6213.380186 s :
# GPT :    6213.382250 s :
# GPT :    6213.384498 s :
# GPT :    6213.386679 s :
# GPT :    6213.389011 s :
# GPT :    6213.391471 s :
# GPT :    6213.393251 s :
# GPT :    6213.395555 s :
# GPT :    6213.396731 s :
# GPT :    6213.398436 s :
# GPT :    6213.400157 s :
# GPT :    6213.402292 s :
# GPT :    6213.408328 s :
# GPT :    6213.410368 s :
# GPT :    6213.412166 s :
# GPT :    6213.413917 s :
# GPT :    6213.415644 s :
# GPT :    6213.417416 s :
# GPT :    6213.419114 s :
# GPT :    6213.420821 s :
# GPT :    6213.422545 s :
# GPT :    6213.424324 s :
# GPT :    6213.426057 s :
# GPT :    6213.428320 s :
# GPT :    6213.429443 s :
# GPT :    6213.431138 s :
# GPT :    6213.432856 s :
# GPT :    6213.434637 s :
# GPT :    6213.436372 s :
# GPT :    6213.438105 s :
# GPT :    6213.439808 s :
# GPT :    6213.441576 s :
# GPT :    6213.443302 s :
# GPT :    6213.445014 s :
# GPT :    6213.446774 s :
# GPT :    6213.448578 s :
# GPT :    6213.450411 s :
# GPT :    6213.452096 s :
# GPT :    6213.453793 s :
# GPT :    6213.456040 s :
# GPT :    6213.457215 s :
# GPT :    6213.458954 s :
# GPT :    6213.462402 s :
# GPT :    6213.464787 s :
# GPT :    6213.467072 s :
# GPT :    6213.469432 s :
# GPT :    6213.471804 s :
# GPT :    6213.473685 s :
# GPT :    6213.475422 s :
# GPT :    6213.477163 s :
# GPT :    6213.478889 s :
# GPT :    6213.480623 s :
# GPT :    6213.482381 s :
# GPT :    6213.484135 s :
# GPT :    6213.485870 s :
# GPT :    6213.488762 s :
# GPT :    6213.489968 s :
# GPT :    6213.491693 s :
# GPT :    6213.493402 s :
# GPT :    6213.495297 s :
# GPT :    6213.497893 s :
# GPT :    6213.500390 s :
# GPT :    6213.502489 s :
# GPT :    6213.504596 s :
# GPT :    6213.507517 s :
# GPT :    6213.509573 s :
# GPT :    6213.511717 s :
# GPT :    6213.514802 s :
# GPT :    6213.517262 s :
# GPT :    6213.519313 s :
# GPT :    6213.521317 s :
# GPT :    6213.523986 s :
# GPT :    6213.525375 s :
# GPT :    6213.527380 s :
# GPT :    6213.530305 s :
# GPT :    6213.532227 s :
# GPT :    6213.533935 s :
# GPT :    6213.535646 s :
# GPT :    6213.537383 s :
# GPT :    6213.539095 s :
# GPT :    6213.541703 s :
# GPT :    6213.543550 s :
# GPT :    6213.545979 s :
# GPT :    6213.548464 s :
# GPT :    6213.550956 s :
# GPT :    6213.552919 s :
# GPT :    6213.554660 s :
# GPT :    6213.556968 s :
# GPT :    6213.558144 s :
# GPT :    6213.559884 s :
# GPT :    6213.561553 s :
# GPT :    6213.563331 s :
# GPT :    6213.565399 s :
# GPT :    6213.567302 s :
# GPT :    6213.569004 s :
# GPT :    6213.570694 s :
# GPT :    6213.572330 s :
# GPT :    6213.574024 s :
# GPT :    6213.575718 s :
# GPT :    6213.577404 s :
# GPT :    6213.579081 s :
# GPT :    6213.580870 s :
# GPT :    6213.582859 s :
# GPT :    6213.585331 s :
# GPT :    6213.586540 s :
# GPT :    6213.588390 s :
# GPT :    6213.590305 s :
# GPT :    6213.592479 s :
# GPT :    6213.594219 s :
# GPT :    6213.595917 s :
# GPT :    6213.597661 s :
# GPT :    6213.599414 s :
# GPT :    6213.601123 s :
# GPT :    6213.602881 s :
# GPT :    6213.604683 s :
# GPT :    6213.606542 s :
# GPT :    6213.608360 s :
# GPT :    6213.610185 s :
# GPT :    6213.611932 s :
# GPT :    6213.614326 s :
# GPT :    6213.615545 s :
# GPT :    6213.617282 s :
# GPT :    6213.619025 s :
# GPT :    6213.620790 s :
# GPT :    6213.622504 s :
# GPT :    6213.624188 s :
# GPT :    6213.626063 s :
# GPT :    6213.627881 s :
# GPT :    6213.629798 s :
# GPT :    6213.631695 s :
# GPT :    6213.633428 s :
# GPT :    6213.635294 s :
# GPT :    6213.637009 s :
# GPT :    6213.638777 s :
# GPT :    6213.640547 s :
# GPT :    6213.642882 s :
# GPT :    6213.644063 s :
# GPT :    6213.645770 s :
# GPT :    6213.647513 s :
# GPT :    6213.649287 s :
# GPT :    6213.651020 s :
# GPT :    6213.652775 s :
# GPT :    6213.654508 s :
# GPT :    6213.657575 s :
# GPT :    6213.659437 s :
# GPT :    6213.661241 s :
# GPT :    6213.662976 s :
# GPT :    6213.664672 s :
# GPT :    6213.666393 s :
# GPT :    6213.668079 s :
# GPT :    6213.669782 s :
# GPT :    6213.671580 s :
# GPT :    6213.673270 s :
# GPT :    6213.675133 s :
# GPT :    6213.677524 s :
# GPT :    6213.678755 s :
# GPT :    6213.680585 s :
# GPT :    6213.682318 s :
# GPT :    6213.684000 s :
# GPT :    6213.685879 s :
# GPT :    6213.687844 s :
# GPT :    6213.689718 s :
# GPT :    6213.691530 s :
# GPT :    6213.693414 s :
# GPT :    6213.695607 s :
# GPT :    6213.697345 s :
# GPT :    6213.699075 s :
# GPT :    6213.701005 s :
# GPT :    6213.703769 s :
# GPT :    6213.705851 s :
# GPT :    6213.708324 s :
# GPT :    6213.709629 s :
# GPT :    6213.720271 s :
# GPT :    6213.723380 s :
# GPT :    6213.725731 s :
# GPT :    6213.728822 s :
# GPT :    6213.731477 s :
# GPT :    6213.733811 s :
# GPT :    6213.736097 s :
# GPT :    6213.738143 s :
# GPT :    6213.739821 s :
# GPT :    6213.741510 s :
# GPT :    6213.743152 s :
# GPT :    6213.744814 s :
# GPT :    6213.746515 s :
# GPT :    6213.748185 s :
# GPT :    6213.751345 s :
# GPT :    6213.752518 s :
# GPT :    6213.754233 s :
# GPT :    6213.756279 s :
# GPT :    6213.758010 s :
# GPT :    6213.760008 s :
# GPT :    6213.761922 s :
# GPT :    6213.763785 s :
# GPT :    6213.765705 s :
# GPT :    6213.767577 s :
# GPT :    6213.769306 s :
# GPT :    6213.772595 s :
# GPT :    6213.774383 s :
# GPT :    6213.776424 s :
# GPT :    6213.778138 s :
# GPT :    6213.780212 s :
# GPT :    6213.782512 s :
# GPT :    6213.784022 s :
# GPT :    6213.785766 s :
# GPT :    6213.787794 s :
# GPT :    6213.789570 s :
# GPT :    6213.791427 s :
# GPT :    6213.793182 s :
# GPT :    6213.795213 s :
# GPT :    6213.797921 s :
# GPT :    6213.799716 s :
# GPT :    6213.801855 s :
# GPT :    6213.803545 s :
# GPT :    6213.805563 s :
# GPT :    6213.807260 s :
# GPT :    6213.809357 s :
# GPT :    6213.811069 s :
# GPT :    6213.813392 s :
# GPT :    6213.814564 s :
# GPT :    6213.816276 s :
# GPT :    6213.817947 s :
# GPT :    6213.819645 s :
# GPT :    6213.821338 s :
# GPT :    6213.823010 s :
# GPT :    6213.824712 s :
# GPT :    6213.826533 s :
# GPT :    6213.828247 s :
# GPT :    6213.829941 s :
# GPT :    6213.831737 s :
# GPT :    6213.833535 s :
# GPT :    6213.835335 s :
# GPT :    6213.837117 s :
# GPT :    6213.838939 s :
# GPT :    6213.841387 s :
# GPT :    6213.842578 s :
# GPT :    6213.844278 s :
# GPT :    6213.845910 s :
# GPT :    6213.848769 s :
# GPT :    6213.850422 s :
# GPT :    6213.852283 s :
# GPT :    6213.854127 s :
# GPT :    6213.856195 s :
# GPT :    6213.858027 s :
# GPT :    6213.859884 s :
# GPT :    6213.861612 s :
# GPT :    6213.863435 s :
# GPT :    6213.865164 s :
# GPT :    6213.866978 s :
# GPT :    6213.868713 s :
# GPT :    6213.871094 s :
# GPT :    6213.872344 s :
# GPT :    6213.874140 s :
# GPT :    6213.875875 s :
# GPT :    6213.877653 s :
# GPT :    6213.879364 s :
# GPT :    6213.881127 s :
# GPT :    6213.882940 s :
# GPT :    6213.884722 s :
# GPT :    6213.886442 s :
# GPT :    6213.888167 s :
# GPT :    6213.890233 s :
# GPT :    6213.892362 s :
# GPT :    6213.894402 s :
# GPT :    6213.896368 s :
# GPT :    6213.898667 s :
# GPT :    6213.902521 s :
# GPT :    6213.904306 s :
# GPT :    6213.906572 s :
# GPT :    6213.908749 s :
# GPT :    6213.910737 s :
# GPT :    6213.912586 s :
# GPT :    6213.914815 s :
# GPT :    6213.917213 s :
# GPT :    6213.919298 s :
# GPT :    6213.921394 s :
# GPT :    6213.923564 s :
# GPT :    6213.925908 s :
# GPT :    6213.928061 s :
# GPT :    6213.930318 s :
# GPT :    6213.932484 s :
# GPT :    6213.935060 s :
# GPT :    6213.937469 s :
# GPT :    6213.938929 s :
# GPT :    6213.943639 s :
# GPT :    6213.946036 s :
# GPT :    6213.948763 s :
# GPT :    6213.950674 s :
# GPT :    6213.952371 s :
# GPT :    6213.954502 s :
# GPT :    6213.956584 s :
# GPT :    6213.958946 s :
# GPT :    6213.961138 s :
# GPT :    6213.963655 s :
# GPT :    6213.967988 s :
# GPT :    6213.971019 s :
# GPT :    6213.972556 s :
# GPT :    6213.974756 s :
# GPT :    6213.976882 s :
# GPT :    6213.978780 s :
# GPT :    6213.980607 s :
# GPT :    6213.982498 s :
# GPT :    6213.984320 s :
# GPT :    6213.986448 s :
# GPT :    6213.988843 s :
# GPT :    6213.991155 s :
# GPT :    6213.993616 s :
# GPT :    6213.995845 s :
# GPT :    6213.998231 s :
# GPT :    6214.000367 s :
# GPT :    6214.002471 s :
# GPT :    6214.004786 s :
# GPT :    6214.005920 s :
# GPT :    6214.007593 s :
# GPT :    6214.009318 s :
# GPT :    6214.010964 s :
# GPT :    6214.012697 s :
# GPT :    6214.014445 s :
# GPT :    6214.016146 s :
# GPT :    6214.017840 s :
# GPT :    6214.019584 s :
# GPT :    6214.021245 s :
# GPT :    6214.022943 s :
# GPT :    6214.024640 s :
# GPT :    6214.026315 s :
# GPT :    6214.027982 s :
# GPT :    6214.029691 s :
# GPT :    6214.032008 s :
# GPT :    6214.036656 s :
# GPT :    6214.039622 s :
# GPT :    6214.042320 s :
# GPT :    6214.044802 s :
# GPT :    6214.047468 s :
# GPT :    6214.049824 s :
# GPT :    6214.051601 s :
# GPT :    6214.053471 s :
# GPT :    6214.055492 s :
# GPT :    6214.057616 s :
# GPT :    6214.059675 s :
# GPT :    6214.061727 s :
# GPT :    6214.063782 s :
# GPT :    6214.065867 s :
# GPT :    6214.067595 s :
# GPT :    6214.069787 s :
# GPT :    6214.070893 s :
# GPT :    6214.072551 s :
# GPT :    6214.074270 s :
# GPT :    6214.075990 s :
# GPT :    6214.077718 s :
# GPT :    6214.079451 s :
# GPT :    6214.081192 s :
# GPT :    6214.082921 s :
# GPT :    6214.084645 s :
# GPT :    6214.086304 s :
# GPT :    6214.088069 s :
# GPT :    6214.089766 s :
# GPT :    6214.091495 s :
# GPT :    6214.093225 s :
# GPT :    6214.094953 s :
# GPT :    6214.097228 s :
# GPT :    6214.098400 s :
# GPT :    6214.100144 s :
# GPT :    6214.101861 s :
# GPT :    6214.103580 s :
# GPT :    6214.105297 s :
# GPT :    6214.107023 s :
# GPT :    6214.108711 s :
# GPT :    6214.110403 s :
# GPT :    6214.112139 s :
# GPT :    6214.113922 s :
# GPT :    6214.115707 s :
# GPT :    6214.117430 s :
# GPT :    6214.119159 s :
# GPT :    6214.120865 s :
# GPT :    6214.122586 s :
# GPT :    6214.124843 s :
# GPT :    6214.126017 s :
# GPT :    6214.127691 s :
# GPT :    6214.129391 s :
# GPT :    6214.131080 s :
# GPT :    6214.132815 s :
# GPT :    6214.134547 s :
# GPT :    6214.136241 s :
# GPT :    6214.137954 s :
# GPT :    6214.139682 s :
# GPT :    6214.141416 s :
# GPT :    6214.143148 s :
# GPT :    6214.144854 s :
# GPT :    6214.146572 s :
# GPT :    6214.148317 s :
# GPT :    6214.150047 s :
# GPT :    6214.152338 s :
# GPT :    6214.153492 s :
# GPT :    6214.155227 s :
# GPT :    6214.156947 s :
# GPT :    6214.158715 s :
# GPT :    6214.160401 s :
# GPT :    6214.162109 s :
# GPT :    6214.163817 s :
# GPT :    6214.165503 s :
# GPT :    6214.167200 s :
# GPT :    6214.168908 s :
# GPT :    6214.170626 s :
# GPT :    6214.172339 s :
# GPT :    6214.174072 s :
# GPT :    6214.177694 s :
# GPT :    6214.180216 s :
# GPT :    6214.183495 s :
# GPT :    6214.185120 s :
# GPT :    6214.187198 s :
# GPT :    6214.189330 s :
# GPT :    6214.191592 s :
# GPT :    6214.193560 s :
# GPT :    6214.195539 s :
# GPT :    6214.203432 s :
# GPT :    6214.205787 s :
# GPT :    6214.207815 s :
# GPT :    6214.209752 s :
# GPT :    6214.211531 s :
# GPT :    6214.213414 s :
# GPT :    6214.216317 s :
# GPT :    6214.218235 s :
# GPT :    6214.220446 s :
# GPT :    6214.223201 s :
# GPT :    6214.224666 s :
# GPT :    6214.226422 s :
# GPT :    6214.228066 s :
# GPT :    6214.229759 s :
# GPT :    6214.231407 s :
# GPT :    6214.233078 s :
# GPT :    6214.234790 s :
# GPT :    6214.236513 s :
# GPT :    6214.238245 s :

# %%
'''
There are two file types here, a .qar file, and a .qar.idx file. The .qar file (presumably) holds all of the actual propagator data and the .idx file 
holds the indices and byte locations of specific propagators for each configuration. for example on the UConn server, there is a psel-prop-psrc-light.qar
file, and the index files exist only for individual configurations, such as traj-1122.qar.idx. 

There is a header for the .qar file, where it tells us byte information about the first configuration, checkpoint.txt file, and an individual point
we see in the .qar header that a full configuration has a byte offset of 10512714934, and a single point has byte offset 221317, along with some
additional data. the .idx file 'header' lists the information about each individual point, giving us a few byte offsets. 

the light psel psrc props, psel-prop-psrc-light.qar is 494097601961 bytes, the single configuration index file, traj-1122.idx is 581953 bytes.

We have one reader for the index files for a given trajectory. The code seems to be working. One issue is that the key to the 
dictionary we are saving for each trajectory is the point xg, but there are 4 different blocks in the index file for each point. 
This must be fixed by adding a second key perhaps. - composite key, the accuracy is included in the key since the accuracy is a degree of freedom
and because we can tell the truth value of the wall sink variable from the form of the accuracy, for wall sinks the acucracy is just a number, for point sink
the accuracy is a number, 0 or 1, followed by .lat. 

The goal is to use the byte offsets in this dictionary from the index file to load the data from the full .qar file.

I think the process is as follows:

1. in the contraction code we load in a set of points, and create a dictionary for the sets of points we want the propagators from
   so we should be able to write the contraction code to get the points, then with the points we can write some code to load in the propagators
   from one point to another. 

2. For the trajectory we are calculating a correlation function in, we load in that trajectory's index file, which tells us all of the byte offsets 
   for the propagators locations in the main .qar file.

3. we load in just the piece of the main .qar file for the trajectory we are dealing with, and then we use the offsets in the idx dictionary
   to load in specific propagators for specific points on the lattice. 

''';

# %%
with open(fn_qar, "rb") as f:
    f.seek(0,2)
    file_size = f.tell()
    print(f"filesize: {file_size} bytes")
# Out:
# filesize: 494097601961 bytes

# %%
with open(fn_idx, "rb") as f:
    f.seek(0,2)
    file_size = f.tell()
    print(f"filesize: {file_size} bytes")
# Out:
# filesize: 581953 bytes

# %%
10512714934/221317
# Out:
# 47500.71135068702

# %%
2128*2128
# Out:
# 4528384

# %%
#load the binary data for a single trajectory.

#loading code structure
